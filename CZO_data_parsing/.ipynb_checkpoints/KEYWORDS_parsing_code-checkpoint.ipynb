# %%
import pandas as pd
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_rows', 400)
pd.set_option('display.max_columns', 100)
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("/home/christian/Downloads/czo-datasets-metadata-2018-02-02.txt")

# %%
key = df1['KEYWORDS']
keys = []
for i in range(0,len(key)):
    row = key[i].split('|')
    for j in range(0, len(row)):
        keys.append(row[j])

# %%
d1 = {}
seen=set()
count = 0

for i in range(len(keys)):
    word = keys[i]
    if word not in seen:
        seen.add(word)
        
        for j in range(len(keys)):
            a_duplicate = keys[j]
            if (word == a_duplicate):
                count += 1   
                
        d1[word] = count
        count =0

# %%
d_sorted1 = sorted(d1.items(), key=lambda x: (-x[1], x[0]))

# %%
d_sorted1
# Out:
# [('hydrology', 48),
#  ('Santa Catalina Mountains', 25),
#  ('New Mexico', 24),
#  ('Temperature', 24),
#  ('precipitation', 24),
#  ('Arizona', 23),
#  ('Precipitation', 22),
#  ('air temperature', 19),
#  ('soil', 19),
#  ('water', 19),
#  ('Hydrology', 18),
#  ('soil moisture', 18),
#  ('soil temperature', 18),
#  ('Soil', 17),
#  ('Valles Caldera', 17),
#  ('GIS', 16),
#  ('Meteorology', 15),
#  ('Calhoun', 14),
#  ('Jemez Mountains', 14),
#  ('hydropedology', 14),
#  ('soil science', 14),
#  ('CZO', 13),
#  ('discharge', 13),
#  ('temperature', 13),
#  ('', 12),
#  ('Carbon', 12),
#  ('LiDAR', 12),
#  ('relative humidity', 12),
#  ('Reynolds Creek', 11),
#  ('meteorology', 11),
#  ('Marshall Gulch', 10),
#  ('climate', 10),
#  ('pH', 10),
#  ('snow depth', 10),
#  ('Oxygen', 9),
#  ('CO2', 8),
#  ('DEM', 8),
#  ('Discharge', 8),
#  ('Forest Service', 8),
#  ('Iron', 8),
#  ('Nitrogen', 8),
#  ('Relative humidity', 8),
#  ('VWC', 8),
#  ('Water balance', 8),
#  ('christina river', 8),
#  ('delta-18O', 8),
#  ('digital elevation model', 8),
#  ('soil water', 8),
#  ('volumetric water content', 8),
#  ('Air Temperature', 7),
#  ('Aluminum', 7),
#  ('Betasso', 7),
#  ('Calcium', 7),
#  ('Magnesium', 7),
#  ('Manganese', 7),
#  ('Met', 7),
#  ('Nitrate', 7),
#  ('PSW', 7),
#  ('Potassium', 7),
#  ('RCEW', 7),
#  ('Relative Humidity', 7),
#  ('Silicon', 7),
#  ('Sodium', 7),
#  ('Soil Moisture', 7),
#  ('Titanium', 7),
#  ('Water Chemistry', 7),
#  ('Wind Speed', 7),
#  ('Zinc', 7),
#  ('deuterium', 7),
#  ('matric potential', 7),
#  ('radiation', 7),
#  ('shale hills', 7),
#  ('stream chemistry', 7),
#  ('stroud water research center', 7),
#  ('white clay creek', 7),
#  ('Antimony', 6),
#  ('Arsenic', 6),
#  ('Barium', 6),
#  ('Beryllium', 6),
#  ('Boron', 6),
#  ('Bromide', 6),
#  ('Cadmium', 6),
#  ('Cerium', 6),
#  ('Chloride', 6),
#  ('Chromium', 6),
#  ('Climate', 6),
#  ('Cobalt', 6),
#  ('Copper', 6),
#  ('Dysprosium', 6),
#  ('EC', 6),
#  ('Electrical conductivity', 6),
#  ('Erbium', 6),
#  ('Europium', 6),
#  ('Fluoride', 6),
#  ('Gadolinium', 6),
#  ('Holmium', 6),
#  ('Isotopes', 6),
#  ('Jemez River', 6),
#  ('Lanthanum', 6),
#  ('Lead', 6),
#  ('Lutetium', 6),
#  ('Meteorological', 6),
#  ('Molybdenum', 6),
#  ('NH4', 6),
#  ('NO2', 6),
#  ('NO3', 6),
#  ('Neodymium', 6),
#  ('Nickel', 6),
#  ('Nitrite', 6),
#  ('Oracle Ridge', 6),
#  ('Orthophosphate', 6),
#  ('Pacific Southwest Research Station', 6),
#  ('Phosphorus', 6),
#  ('Praseodymium', 6),
#  ('Samarium', 6),
#  ('Selenium', 6),
#  ('Shale Hills', 6),
#  ('Sierra National Forest', 6),
#  ('Silver', 6),
#  ('Snow', 6),
#  ('Strontium', 6),
#  ('Sulfate', 6),
#  ('Terbium', 6),
#  ('Thallium', 6),
#  ('Thulium', 6),
#  ('Tin', 6),
#  ('Uranium', 6),
#  ('Vanadium', 6),
#  ('Ytterbium', 6),
#  ('Yttrium', 6),
#  ('Zirconium', 6),
#  ('aspect', 6),
#  ('d18O', 6),
#  ('delta-D. dD', 6),
#  ('electrical conductivity', 6),
#  ('stable isotopes', 6),
#  ('streamflow', 6),
#  ('well', 6),
#  ('wind speed', 6),
#  ('B1', 5),
#  ('Fluorescence index', 5),
#  ('Gordon Gulch', 5),
#  ('Groundwater', 5),
#  ('Lower Gordon Gulch', 5),
#  ('Net Radiation', 5),
#  ('O2', 5),
#  ('Pressure', 5),
#  ('Reynolds Creek Experimental Watershed', 5),
#  ('SEKI', 5),
#  ('Sequoia National Park', 5),
#  ('Shortwave Radiation', 5),
#  ('Soil temperature', 5),
#  ('Upper Gordon Gulch', 5),
#  ('Wolverton', 5),
#  ('czo', 5),
#  ('dielectric constant', 5),
#  ('eddy covariance', 5),
#  ('instrument clusters', 5),
#  ('map', 5),
#  ('oxygen-18', 5),
#  ('stream water chemistry', 5),
#  ('water table', 5),
#  ('Barometric pressure', 4),
#  ('Biomass', 4),
#  ('CZT', 4),
#  ('California', 4),
#  ('Davis', 4),
#  ('Geochemistry', 4),
#  ('Geophysics', 4),
#  ('Humification index', 4),
#  ('KREW', 4),
#  ('Meteorlogy', 4),
#  ('Morphometry', 4),
#  ('Rain', 4),
#  ('Sap Flow', 4),
#  ('Snow Depth', 4),
#  ('Solute chemistry', 4),
#  ('Stream Water', 4),
#  ('Topography', 4),
#  ('Transpiration', 4),
#  ('USDA-ARS', 4),
#  ('UV Absorbance', 4),
#  ('Wind Direction', 4),
#  ('angelo reserve', 4),
#  ('anions', 4),
#  ('biomass', 4),
#  ('bulk electrical conductivity', 4),
#  ('cations', 4),
#  ('critical zone tree', 4),
#  ('diameter', 4),
#  ('land use', 4),
#  ('lidar', 4),
#  ('mid-elevation', 4),
#  ('moisture', 4),
#  ('pennsylvania', 4),
#  ('rainfall', 4),
#  ('stream flow', 4),
#  ('stream temperature', 4),
#  ('streams', 4),
#  ('topography', 4),
#  ('tree', 4),
#  ('vegetation', 4),
#  ('water isotopes', 4),
#  ('water potential', 4),
#  ('wind direction', 4),
#  ('Anions', 3),
#  ('Barometric Pressure', 3),
#  ('Carbon dioxide', 3),
#  ('Cations', 3),
#  ('Critical Zone', 3),
#  ('Critical Zone Observatory', 3),
#  ('Desert', 3),
#  ('Digital Elevation Model', 3),
#  ('EEMT', 3),
#  ('Energy', 3),
#  ('Geology', 3),
#  ('Groundwater Depth', 3),
#  ('Infiltration experiment', 3),
#  ('Luquillo', 3),
#  ('Mass transfer', 3),
#  ('Metals', 3),
#  ('Missed Grouse', 3),
#  ('Mount Bigelow', 3),
#  ('New Mexico.', 3),
#  ('SUVA', 3),
#  ('Snow depth', 3),
#  ('Soil Temperature', 3),
#  ('Soil gas', 3),
#  ('Specific UV Absorbance', 3),
#  ('Time Lapse Camera', 3),
#  ('Transect', 3),
#  ('UVA', 3),
#  ('White Clay Creek Watershed', 3),
#  ('barometric pressure', 3),
#  ('concentration-discharge', 3),
#  ('ecohydrology', 3),
#  ('ecology', 3),
#  ('flux tower', 3),
#  ('geophysical monitoring', 3),
#  ('ground penetrating radar', 3),
#  ('groundwater', 3),
#  ('land classification', 3),
#  ('leaf area index', 3),
#  ('location', 3),
#  ('manual', 3),
#  ('oxygen and hydrogen stable isotopes', 3),
#  ('rivers', 3),
#  ('sap flow', 3),
#  ('sensors', 3),
#  ('shallow seismic refraction', 3),
#  ('shortwave radiation', 3),
#  ('slope position', 3),
#  ('soil chemistry', 3),
#  ('soil gas', 3),
#  ('soil organic carbon', 3),
#  ('solar radiation', 3),
#  ('species', 3),
#  ('stream', 3),
#  ('survey', 3),
#  ('trees', 3),
#  ('water balance', 3),
#  ('white fir', 3),
#  ('wind', 3),
#  ('Arizona.', 2),
#  ('Boulder Creek', 2),
#  ('Bulk Electrical Conductivity', 2),
#  ('Carbon Dioxide', 2),
#  ('Christina River', 2),
#  ('Clay', 2),
#  ('DO', 2),
#  ('DSM', 2),
#  ('Dew point temperature', 2),
#  ('Digital Surface Model', 2),
#  ('EMI', 2),
#  ('Flux Tower', 2),
#  ('Green Lakes Valley', 2),
#  ('Groundwater chemistry', 2),
#  ('Heat Flux', 2),
#  ('Humidity', 2),
#  ('Jaramillo', 2),
#  ('Jemez', 2),
#  ('Jemez Mountain', 2),
#  ('LIDAR', 2),
#  ('La Jara', 2),
#  ('Mercury', 2),
#  ('Middle Pit', 2),
#  ('Moisture', 2),
#  ('Moisture and Temperature Sensors', 2),
#  ('Mt. Bigelow', 2),
#  ('Pennsylvania', 2),
#  ('Providence', 2),
#  ('Puerto Rico', 2),
#  ('RH', 2),
#  ('Radiation', 2),
#  ('Redondo', 2),
#  ('Redox potential', 2),
#  ('Reduction potential', 2),
#  ('Slope', 2),
#  ('Soil Geochemistry', 2),
#  ('Soil Mineralogy', 2),
#  ('Soil Water', 2),
#  ('Soil moisture', 2),
#  ('Soil water chemistry', 2),
#  ('Stream discharge', 2),
#  ('Streamflow', 2),
#  ('Stroud Water Research Center', 2),
#  ('Surface', 2),
#  ('Surface water chemistry', 2),
#  ('Terrain', 2),
#  ('Valle Caldera', 2),
#  ('Volumetric water content', 2),
#  ('Water Potential', 2),
#  ('Water Vapor', 2),
#  ('White Clay Creek', 2),
#  ('Wind direction', 2),
#  ('Wind speed', 2),
#  ('XRD', 2),
#  ('boundaries', 2),
#  ('brandywine creek', 2),
#  ('canopy closure', 2),
#  ('canopy height', 2),
#  ('clay', 2),
#  ('crown closure', 2),
#  ('curvature', 2),
#  ('deep soil', 2),
#  ('delta-13C', 2),
#  ('delta-D', 2),
#  ('dendrochronology', 2),
#  ('dissolved organic carbon (DOC)', 2),
#  ('douglas fir', 2),
#  ('elevation', 2),
#  ('extracellular enzyme activity', 2),
#  ('geochemistry', 2),
#  ('geology', 2),
#  ('geomorphology', 2),
#  ('geophysics', 2),
#  ('ground water', 2),
#  ('groundwater chemistry', 2),
#  ('height', 2),
#  ('hillshade', 2),
#  ('hyperspectral', 2),
#  ('instrumentation', 2),
#  ('leaf litter', 2),
#  ('locations', 2),
#  ('madrone', 2),
#  ('north', 2),
#  ('photographs', 2),
#  ('pipette method', 2),
#  ('rain', 2),
#  ('rating curve', 2),
#  ('rivendell', 2),
#  ('rock', 2),
#  ('root density', 2),
#  ('root distribution', 2),
#  ('rooting depth', 2),
#  ('sand', 2),
#  ('shale Hills', 2),
#  ('silt', 2),
#  ('snow', 2),
#  ('soil electrical conductivity', 2),
#  ('soil horizon', 2),
#  ('soil thickness', 2),
#  ('soil water chemistry', 2),
#  ('soils', 2),
#  ('south', 2),
#  ('spatial data', 2),
#  ('stream water', 2),
#  ('surface water chemistry', 2),
#  ('texture', 2),
#  ('tree water', 2),
#  ('water vapor', 2),
#  ('watersheds', 2),
#  ('weather', 2),
#  (' ANC        ANC/alkalinity', 1),
#  (' Abs Pres', 1),
#  (' Acid phosphatase;  Al- Ammonium oxalate-extractable; Al- Citrate/ascorbate-extractable; Al in 0.5 M HCl; Al',
#   1),
#  (' Acronyms: DOY = Day of Year DOC = Dissolved Organic Carbon DOM = Dissolved Organic Matter FI = Fluorescence Index HIX = Humification Index BIX = Freshness Index',
#   1),
#  (' CDOM', 1),
#  (' CO2', 1),
#  (' CO3        Carbonate', 1),
#  (' Ca        Calcium', 1),
#  (' Cl        Chloride', 1),
#  (' Cond        Conductivity', 1),
#  (' DIC        Dissolved inorganic carbon', 1),
#  (' DKN        Dissolved Kjeldahl nitrogen', 1),
#  (' DOC        Dissolved organic carbon', 1),
#  (' DON        Dissolved organic nitrogen', 1),
#  (' Electrical conductivity', 1),
#  (' F        Fluoride', 1),
#  (' Ground water depth', 1),
#  (' HCO3        Bicarbonate', 1),
#  (' Hardness        Hardness', 1),
#  (' Humification index', 1),
#  (' K        Potassium', 1),
#  (' Light Intensity', 1),
#  (' Mg        Magnesium', 1),
#  (' NH4        Ammonium', 1),
#  (' NH4-N        Ammonium-N', 1),
#  (' NO2-N        Nitrite-N', 1),
#  (' NO3        Nitrate', 1),
#  (' NO3+NO2        Nitrate + nitrite', 1),
#  (' NO3-N        Nitrate-N', 1),
#  (' NO3-N+NO2-N        Nitrate-N + nitrite-N', 1),
#  (' Na        Sodium', 1),
#  (' Nitrate (NO3)', 1),
#  (' PO4-IC        Orthophosphate by IC', 1),
#  (' POC        Particulate organic carbon', 1),
#  (' SO4-S        Sulfate', 1),
#  (' SRP        Soluble reactive phosphorus', 1),
#  (' Si        Silica', 1),
#  (' TDN        Total dissolved nitrogen', 1),
#  (' TDP        Total dissolved phosphorus', 1),
#  (' TKN-unf        Total Kjeldahl nitrogen (unfiltered)', 1),
#  (' TN-unf Total nitrogen (unfiltered)', 1),
#  (' TOC        Total organic carbon', 1),
#  (' TP-unf        Total phosphorus (unfiltered)', 1),
#  (' Temperature', 1),
#  (' Turbidity', 1),
#  (' White Clay Creek', 1),
#  (' hydrology', 1),
#  (' pH        pH', 1),
#  (' stable isotopes', 1),
#  ('1 meter', 1),
#  ('13C stable isotopes', 1),
#  ('Air T', 1),
#  ('Al        Total Aluminum', 1),
#  ('Albedo', 1),
#  ('Alkalinity', 1),
#  ('Ammonium oxalate-extractable;  Silt;  Soil C;  Soil N;  Soluble phenolics in deionized water extractions;  Xylosidase; ',
#   1),
#  ('Amorph', 1),
#  ('Apogee', 1),
#  ('Archaea', 1),
#  ('Argyllic', 1),
#  ('Aspect', 1),
#  ('BP', 1),
#  ('Bathymetry', 1),
#  ('Bayes theorem', 1),
#  ('Bedrock elevation', 1),
#  ('Berkeley', 1),
#  ('Bisley', 1),
#  ('Bulk density', 1),
#  ('CH4', 1),
#  ('CO2 Concentration', 1),
#  ('CO2 Flux', 1),
#  ('CO2 concentration', 1),
#  ('CO2 efflux', 1),
#  ('CO2 respiration', 1),
#  ('COSMOS', 1),
#  ('CZMW bore wells', 1),
#  ('Ca', 1),
#  ('Calhoun CZO', 1),
#  ('Campbell', 1),
#  ('Canopy Trimming experiment', 1),
#  ('Catena', 1),
#  ('Chemistry', 1),
#  ('Christina River basin', 1),
#  ('Climatology', 1),
#  ('CoRIS', 1),
#  ('Colloids', 1),
#  ('Conductivity', 1),
#  ('Cosmogenic Nuclides', 1),
#  ('DBH', 1),
#  ('DNA', 1),
#  ('DSMs', 1),
#  ('DUST', 1),
#  ('Depth', 1),
#  ('Depth Breast Height', 1),
#  ('Didymosphenia Geminata', 1),
#  ('Dissolved Oxygen', 1),
#  ('Dissolved organic matter', 1),
#  ('Disturbance inorganic nutrients', 1),
#  ('ET', 1),
#  ('Ecology', 1),
#  ('El Yunque National Forest', 1),
#  ('Electrical Conductivity', 1),
#  ('Electrical Resistivity', 1),
#  ('Evapotranspiration', 1),
#  ('Exchangeable Ca++', 1),
#  ('Exchangeable K+', 1),
#  ('Exchangeable Mg++', 1),
#  ('FO-DTS', 1),
#  ('Flux-PIHM', 1),
#  ('Frijoles Canyon', 1),
#  ('GP bore-wells', 1),
#  ('GPR', 1),
#  ('Gage height', 1),
#  ('Geomorphology', 1),
#  ('Germanium', 1),
#  ('Google Maps', 1),
#  ('Granite', 1),
#  ('Groundwater Meteorological', 1),
#  ('Groundwater Temperatures', 1),
#  ('Groundwater water table', 1),
#  ('High density LiDAR', 1),
#  ('History Grove', 1),
#  ('Hydrogen Isotopes', 1),
#  ('Hydrology reanalysis', 1),
#  ('Idaho', 1),
#  ('Jaramillo Creek', 1),
#  ('K', 1),
#  ('K-sat', 1),
#  ('KMZ', 1),
#  ('Kaolinite', 1),
#  ('Ksat', 1),
#  ('LDO', 1),
#  ('LDO%', 1),
#  ('LOI', 1),
#  ('La Jara Creek', 1),
#  ('Land cover', 1),
#  ('Landcover', 1),
#  ('Landscape Position', 1),
#  ('Las Conchas fire', 1),
#  ('Leaf litter', 1),
#  ('Leaves. Oaks', 1),
#  ('Litter decomposition', 1),
#  ('Litterfall', 1),
#  ('LongWave Radiation', 1),
#  ('METAR', 1),
#  ('MPS', 1),
#  ('Marshall Gutch', 1),
#  ('Merced', 1),
#  ('Meteoric beryllium-10', 1),
#  ('Mg', 1),
#  ('Mica', 1),
#  ('Mineralogy', 1),
#  ('Morphologic Horizon', 1),
#  ('N2O', 1),
#  ('N2O Concentration', 1),
#  ('NADP', 1),
#  ('Na', 1),
#  ('National Atmospheric Deposition Program', 1),
#  ('Net radiation', 1),
#  ('Niobium', 1),
#  ('Nitrogen deposition', 1),
#  ('None', 1),
#  ('North Facing', 1),
#  ('OpenTopography', 1),
#  ('Oxygen Isotopes', 1),
#  ('PAR', 1),
#  ('PARAFAC', 1),
#  ('PIHM', 1),
#  ('PN', 1),
#  ('POC', 1),
#  ('Particle Size Change', 1),
#  ('Pines', 1),
#  ('Pit1', 1),
#  ('Pit2', 1),
#  ('Pit3', 1),
#  ('Pit4', 1),
#  ('Pit5', 1),
#  ('Point Cloud', 1),
#  ('Precipitation Frequency.', 1),
#  ('Precipitation Intensity', 1),
#  ('Quartz', 1),
#  ('RFID PIT', 1),
#  ('Rayleigh scattering', 1),
#  ('Reanalysis', 1),
#  ('Redondo Creek', 1),
#  ('Regolith', 1),
#  ('Reservoir height', 1),
#  ('Residence Time', 1),
#  ('Rio Blanco', 1),
#  ('Rio Mameyes', 1),
#  ('SUVA254', 1),
#  ('SYNOP', 1),
#  ('Sand', 1),
#  ('Sediment Transport', 1),
#  ('Sediment tracers', 1),
#  ('Seep', 1),
#  ('Senescence', 1),
#  ('Shallow Seismic Refraction', 1),
#  ('Shavers Creek', 1),
#  ('Shrubs', 1),
#  ('Si', 1),
#  ('Silt', 1),
#  ('Snow sensors', 1),
#  ('Soil CO2', 1),
#  ('Soil Hydraulic Conductivity', 1),
#  ('Soil N2O', 1),
#  ('Soil Properties', 1),
#  ('Soil Texture', 1),
#  ('Soil Trace gases', 1),
#  ('Soil geochemistry', 1),
#  ('Soil organic matter', 1),
#  ('Soil texture', 1),
#  ('Soil;  Sand;  Silica-Citrate/ascorbate-extractable;  Silica in 0.5 M HCl;  Silica',
#   1),
#  ('Soils', 1),
#  ('Solar Radiation', 1),
#  ('Solar radiation', 1),
#  ('South Facing', 1),
#  ('Spatial distribution', 1),
#  ('Specific Conductance', 1),
#  ('Specific Ultraviolet Absorption', 1),
#  ('Specific conductance', 1),
#  ('Stable isotope', 1),
#  ('Stage', 1),
#  ('Stream Flow', 1),
#  ('Stream Temperature', 1),
#  ('Stream and groundwater chemistry', 1),
#  ('Stream flow', 1),
#  ('Streams', 1),
#  ('Subsoil', 1),
#  ('TDR', 1),
#  ('TLS', 1),
#  ('TMR', 1),
#  ('Terrestrial laser scan', 1),
#  ('Throughfall', 1),
#  ('Totals', 1),
#  ('Tree fall', 1),
#  ('Trees', 1),
#  ('Turbidity', 1),
#  ('UVA254', 1),
#  ('Ultraviolet Absorption', 1),
#  ('Urbanization', 1),
#  ('Vaisala', 1),
#  ('Vegetation', 1),
#  ('Vegetation transect', 1),
#  ('Volumetric Water Content', 1),
#  ('Water Quality', 1),
#  ('Water Resources', 1),
#  ('Water potential', 1),
#  ('Wet Tropical Forest', 1),
#  ('X-Ray Diffraction', 1),
#  ('X-ray Florescence', 1),
#  ('X-ray Fluorescence', 1),
#  ('X-ray diffraction', 1),
#  ('XRF', 1),
#  ('acid phosphatase', 1),
#  ('aerial photography', 1),
#  ('aggregates', 1),
#  ('agriculture', 1),
#  ('agroecosystems & environment', 1),
#  ('alder', 1),
#  ('alkalinity', 1),
#  ('and 3D wind speed', 1),
#  ('apparent resistivity', 1),
#  ('aquatic ecosystems', 1),
#  ('areas', 1),
#  ('argillite', 1),
#  ('atmospheric pressure', 1),
#  ('bacteria', 1),
#  ('bare-earth', 1),
#  ('bed load transport', 1),
#  ('biogeochemistry', 1),
#  ('boundary', 1),
#  ('boundary layer', 1),
#  ('branscomb', 1),
#  ('bulk soil moisture', 1),
#  ('calhoun', 1),
#  ('canopy cover', 1),
#  ('carbon dioxide', 1),
#  ('carbon flux', 1),
#  ('cation', 1),
#  ('census data', 1),
#  ('chemistry', 1),
#  ('citrate/ditihionite extractable;  Alpha-N-acetylglucosaminidase;  Beta Glucosidase;  Bulk density;  C percent in live fine roots;  C:N;  Calcium;  Cellobiohydrolase;  Clay; dead fine roots;  DOC in 0.5M HCl extractions;  DOC in deionized water extractions;  Fe- Ammonium oxalate-extractable;  Fe- citrate/dithionite extractable;  Fe-citrate/ascorbate extractable;  Fe(III) in 0.5 M HCl;  Potassium;  Live fine roots;  Mass;  Magnesium;  Mn- Citrate/ascorbate-extractable;  Mn- in 0.5M HCl extraction; N percent in live fine roots; Phosphorus;  pH',
#   1),
#  ('cloud water', 1),
#  ('coarse woody debris', 1),
#  ('coastal belt', 1),
#  ('common offset', 1),
#  ('conductivity', 1),
#  ('control points', 1),
#  ('cosmic rays', 1),
#  ('critical zone observatory', 1),
#  ('cross-watershed', 1),
#  ('d13C', 1),
#  ('debris', 1),
#  ('deep core', 1),
#  ('delaware', 1),
#  ('delta-13C of DIC', 1),
#  ('delta-18O of H2O', 1),
#  ('delta-C', 1),
#  ('delta-D of H2O', 1),
#  ('dem', 1),
#  ('dendrometer', 1),
#  ('density', 1),
#  ('diatom', 1),
#  ('dielectric', 1),
#  ('dissolved organic carbon', 1),
#  ('disturbance history', 1),
#  ('ecosystems', 1),
#  ('eel river', 1),
#  ('electric resistivity', 1),
#  ('electrical resistivity', 1),
#  ('electrical resistivity imaging', 1),
#  ('electromagnetic induction', 1),
#  ('elements', 1),
#  ('energy flux', 1),
#  ('enzyme kinetics', 1),
#  ('erosion', 1),
#  ('extracellular enzymes', 1),
#  ('extractable organic carbon', 1),
#  ('extreme events', 1),
#  ('feature extraction', 1),
#  ('field areas', 1),
#  ('flat', 1),
#  ('flow accumulation', 1),
#  ('fluorescence', 1),
#  ('fluxes', 1),
#  ('fog water', 1),
#  ('foliage', 1),
#  ('forest canopy structure', 1),
#  ('fractured rock', 1),
#  ('freshwater', 1),
#  ('gage height', 1),
#  ('gas wells', 1),
#  ('gasses', 1),
#  ('gauge height', 1),
#  ('gauges', 1),
#  ('geospatial data', 1),
#  ('gordon gulch', 1),
#  ('greenhouse', 1),
#  ('ground heat flux', 1),
#  ('ground water depth', 1),
#  ('ground water temperature', 1),
#  ('groundwater level', 1),
#  ('groundwater temperature', 1),
#  ('growth', 1),
#  ('gullies', 1),
#  ('hail diameter', 1),
#  ('heat pulse flowmeter', 1),
#  ('heterotrophic respiration', 1),
#  ('high resolution DEM', 1),
#  ('hillslope', 1),
#  ('historic images', 1),
#  ('historical data', 1),
#  ('historical photographs', 1),
#  ('holcombe\xe2\x80\x99s branch', 1),
#  ('humidity', 1),
#  ('hydraulic conductivity', 1),
#  ('hydrogen', 1),
#  ('hydrometeor species', 1),
#  ('hydrometeors', 1),
#  ('insolation', 1),
#  ('intermittent spring water chemistry', 1),
#  ('invertebrates', 1),
#  ('iron redox', 1),
#  ('isco sampler', 1),
#  ('isotopes', 1),
#  ('land use change', 1),
#  ('land use history', 1),
#  ('landforms', 1),
#  ('landslides', 1),
#  ('latent heat', 1),
#  ('leaf area', 1),
#  ('leaf senescence', 1),
#  ('leaf-off', 1),
#  ('leaf-on', 1),
#  ('lithology', 1),
#  ('live oak', 1),
#  ('lodgepole pine', 1),
#  ('logged', 1),
#  ('long wave and short wave radiation', 1),
#  ('longwave', 1),
#  ('lysimeter water chemistry', 1),
#  ('macroinvertebrate indices', 1),
#  ('maple', 1),
#  ('mapping', 1),
#  ('metals', 1),
#  ('microbial community structure', 1),
#  ('mobile regolith', 1),
#  ('municipalities', 1),
#  ('natural gamma', 1),
#  ('natural gamma ray logging', 1),
#  ('ncalm', 1),
#  ('net radiation', 1),
#  ('network', 1),
#  ('neutron', 1),
#  ('neutron count', 1),
#  ('nitrogen oxides', 1),
#  ('numerical modeling', 1),
#  ('oak', 1),
#  ('optical borehole imaging', 1),
#  ('organic horizon', 1),
#  ('organic matter', 1),
#  ('organisms', 1),
#  ('oxygen', 1),
#  ('oxygen concentration', 1),
#  ('ozone', 1),
#  ('pCO2', 1),
#  ('par', 1),
#  ('particulate organic carbon', 1),
#  ('phosphorus', 1),
#  ('phosphorus; parent material; topography; Puerto Rico; state factors.', 1),
#  ('photosynthetically active radiation', 1),
#  ('pine', 1),
#  ('pinus contorta', 1),
#  ('pinus ponderosa', 1),
#  ('pit', 1),
#  ('pit and mound topography', 1),
#  ('pits', 1),
#  ('plant physiology', 1),
#  ('plant species', 1),
#  ('pole transects', 1),
#  ('poles', 1),
#  ('pollution', 1),
#  ('ponderosa', 1),
#  ('ponderosa pine', 1),
#  ('populations', 1),
#  ('porosity', 1),
#  ('post-wildfire', 1),
#  ('potassium concentration', 1),
#  ('precipitation intensity', 1),
#  ('precipitation type', 1),
#  ('primary production', 1),
#  ('probe', 1),
#  ('rain-snow transition zone', 1),
#  ('raster', 1),
#  ('reference 3', 1),
#  ('reference 4', 1),
#  ('regions', 1),
#  ('residence time', 1),
#  ('reynolds creek', 1),
#  ('rock cover', 1),
#  ('rock moisture', 1),
#  ('rock size', 1),
#  ('root ball', 1),
#  ('root length', 1),
#  ('root temperature', 1),
#  ('roots', 1),
#  ('runoff', 1),
#  ('sagebrush', 1),
#  ('sample sites', 1),
#  ('sap flux', 1),
#  ('saprolite', 1),
#  ('sediment transport', 1),
#  ('seepage rate', 1),
#  ('seismic surveys', 1),
#  ('semi-arid', 1),
#  ('sensible heat', 1),
#  ('sequential filtration', 1),
#  ('shale', 1),
#  ('shaver\xe2\x80\x99s creek', 1),
#  ('shortwave', 1),
#  ('single point resistance', 1),
#  ('sites', 1),
#  ('slope', 1),
#  ('slope aspect', 1),
#  ('snow melt', 1),
#  ('snow pit', 1),
#  ('snow pits', 1),
#  ('snow survey', 1),
#  ('soil CO2', 1),
#  ('soil Moisture', 1),
#  ('soil cores', 1),
#  ('soil depth', 1),
#  ('soil evapotranspiration', 1),
#  ('soil geochemistry', 1),
#  ('soil hydology', 1),
#  ('soil microbes', 1),
#  ('soil microbial activity', 1),
#  ('soil microbial communities', 1),
#  ('soil organic nitrogen', 1),
#  ('soil pH', 1),
#  ('soil pore-water', 1),
#  ('soil porosity', 1),
#  ('soil profile', 1),
#  ('soil respiration', 1),
#  ('soil sensors', 1),
#  ('soil texture', 1),
#  ('solute chemistry', 1),
#  ('solute tracer test', 1),
#  ('south fork eel river', 1),
#  ('specific conductance', 1),
#  ('stage', 1),
#  ('stem', 1),
#  ('stem psychrometer', 1),
#  ('stilling well', 1),
#  ('stream ecology', 1),
#  ('stream gauge', 1),
#  ('streambed temperature', 1),
#  ('substrates', 1),
#  ('subsurface flow', 1),
#  ('sunlight', 1),
#  ('surface flux', 1),
#  ('surface pressure', 1),
#  ('suspended load', 1),
#  ('suspended sediment', 1),
#  ('susquehanna', 1),
#  ('tan oak', 1),
#  ('temperature fluid resistivity', 1),
#  ('tensile strength', 1),
#  ('tensiometer', 1),
#  ('terrain conductivity', 1),
#  ('terrestrial laser mapping', 1),
#  ('terrrace', 1),
#  ('thermal data', 1),
#  ('thorium concentration', 1),
#  ('time-series', 1),
#  ('topographic wetness index', 1),
#  ('tracer', 1),
#  ('transects', 1),
#  ('transit time', 1),
#  ('transition zone', 1),
#  ('transpiration', 1),
#  ('tree diameter', 1),
#  ('tree growth', 1),
#  ('tree height', 1),
#  ('tree physiology', 1),
#  ('tree ring', 1),
#  ('tropical subsoil', 1),
#  ('turbidity', 1),
#  ('understory', 1),
#  ('upper Gordon Gulch', 1),
#  ('uranium concentration', 1),
#  ('van Genuchten parameters', 1),
#  ('vegetation cover', 1),
#  ('vegetation survey', 1),
#  ('virtual temperature', 1),
#  ('volatile organic compounds', 1),
#  ('water chemistry', 1),
#  ('water depth', 1),
#  ('water flux', 1),
#  ('water level', 1),
#  ('water temperature', 1),
#  ('water use efficiency', 1),
#  ('water vapor concentration', 1),
#  ('watershed', 1),
#  ('weathered bedrock', 1),
#  ('weathering', 1),
#  ('weathering front', 1),
#  ('well water levels', 1),
#  ('wireless sensor', 1),
#  ('wood', 1),
#  ('\xce\xb413C', 1),
#  ('\xce\xb415N', 1),
#  ('\xce\xb418O', 1),
#  ('\xce\xb42H', 1)]

# %%
#Run this to create a txt file and store the list
with open('keywords.txt', 'w') as fp:
    fp.write('\n'.join('%s %s' % x for x in d_sorted1))
