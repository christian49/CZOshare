# %%
import pandas as pd
import re

# %%
df = pd.read_csv("/home/christian/Downloads/czo-datasets-metadata-2018-03-01c.csv")
key = df['VARIABLES']
keys = []

for i in range(0,len(key)):
    row = key[i].split('|')
        
    for j in range(0, len(row)):
        k = row[j].lower()
        k = k.replace("-", "")
        k = k.replace("#", "")
        k = k.replace(" ", "")
        k = k.replace("\t","")
        k = k.replace("(m)","")
        k = k.replace("(g)","")
        k = k.replace("(%)","")
        k = k.replace("_", "")
        keys.append(k)

# %%
df1 = pd.read_csv("odmCV.csv")
odmcv = []
for i in df1:
    odmcv.append(i)

# %%
d1 = {}
seen=set()
count = 0
for i in range(len(keys)):
    word = keys[i]
    if word not in seen:
        seen.add(word)
        
        for j in range(len(keys)):
            a_duplicate = keys[j]
            if (word == a_duplicate):
                count += 1   

        d1[word] = count
        count =0
        
d_sorted1 = sorted(d1.items(), key=lambda x: (-x[1], x[0]))

# %%
variables = sorted(seen)
sep = ','
odmTerm=[]
for i in range(0,len(odmcv)):
    row = odmcv[i].split(sep,1)[0]
    odmTerm.append(row)

# %%
len(variables)
# Out:
# 1845

# %%
matchTerms=[]
#Looking for variables that have relations with ODM2 terms
for i in range(0,len(odmTerm)):
    pattern = re.compile(re.escape(odmTerm[i]))
    for j in range(0,len(variables)):
        result = pattern.search(variables[j])
        if result:
            matchTerms.append(odmTerm[i])
            break

# %%
# removing variables that have relation with ODM2 terms, so we end with a list of variables 
matchVariables=[]
for i in range(0,len(matchTerms)):
    pattern = re.compile(re.escape(matchTerms[i]))
    for j in variables[-1::-1]:
        result = pattern.search(j)
        if result:
            matchVariables.append(j)
            del variables[variables.index(j)]
# Out:
# μgsocg1
# μgeocg1
# δ2hreportablevalue(permil)
# δ2h(‰)
# δ2h(permil)
# δ2h
# δ18oreportablevalue(permil)
# δ18o(‰)
# δ18o
# δ13csoilrespiredco2
# δ13csoc
# δ13ceoc
# βglucosidaseactivity
# zr
# yttriumdissolved
# ytterbiumdissolved
# ymax
# year
# yb
# y
# xrf
# xrd
# xmax
# x
# wtemp
# wsscalavg
# wsmax
# wool(lbs.)
# woodymaterial
# wheat(bushels)
# watertempc
# watertemp(°c)
# watertemp(c)
# watertableraw(mv
# watertable(mmorcm)
# watertable
# waterquality
# waterlevel(ft)
# waterlevel
# waterflux
# waterdepth(cm)
# waterdepth
# w
# vllydpth
# vertical
# vermiculite
# vbat
# valueoforchardproducts(dollars)
# valueoflivestock
# value
# v(μm)
# v
# uva280.
# uva280
# uva254
# utme
# u
# twi
# tsargorodtsevite
# tritium1sigma
# tritium(tu)
# treetype
# treespecies
# treeid
# treegroup
# treegirth1.5m
# treeazimuth
# tree
# trapid
# tpi
# tp(um/l)
# totalzr(mg/g)
# totalppfd
# totalp(ug/l)
# totalp
# totalorgc(mg/l)
# totallittercollected
# totalfe(mg/g)
# totaldissolvedp(ugp/l)
# totaldissolvedp(ug/l)
# totalca(mg/g)
# totalal(mg/g)
# total9be(ug/g)
# total
# tobacco(lbs.)
# tmstamp(yyyymmddhh:mm:ss)
# tmstamp
# tm
# tl
# tio2
# tilepushprobedepth(cm)
# ti(ug/ml)
# ti
# thuliumdissolved
# th
# terbiumdissolved
# tds(mg1)
# tdp(um/l)
# tcdtavg
# tc(mg/l)
# tb
# taup
# ta
# t1c
# t+e(m/day)
# sweetpotatoes(bushels)
# suva280.
# suva280
# surfdegc
# sum+
# sum
# streamwaterchemistry
# stdht
# state
# start
# stagem
# stagediff
# stagecm
# ssurgoid
# ss
# sr(μm)
# sr(umoll1)
# sr(ug/ml)
# sr(mg/l)
# sr
# species
# spc(mscm1)
# solradtot
# solradposs
# soilvwc
# soiltype
# soiltracegases
# soiltexture
# soiltemp(c)22cm
# soiltemp(c)15cm
# soilt
# soils
# soilorder
# soilmoisture.
# soilmoisture(m3/m3)
# soilmoisture(40cm;m3/m3)
# soilmoisture(20cm;m3/m3)
# soilmoisture(10cm;m3/m3)
# soilmoisture
# soilheatflux(w/m^2)15cm
# soilec
# soileb
# soildepth
# soilco2(ppm)
# soilc
# so4s
# so4=(ueq/l)
# so4=(ppm)
# so42(μm)
# so42(umoll1)
# so4(mg/l)
# so4
# smp
# sm
# siteid
# site
# sio2icp(ppm)
# sio2(mg/l)
# sio2
# siicp(ppm)
# si28(ug/l)
# si28(mg/l)
# si(μm)
# si(umoll1)
# si(ug/ml)
# si(mg/l)
# si
# shortaxis
# sheep
# shapefiles
# shadedrelief
# semta
# selai
# seedetailsbelow)
# seedetailbelow)
# se
# scale
# sc
# sb
# sapfluxid
# sapflux
# sapflow
# sampletype
# samplemedium
# samplelabel
# sampleid
# sampledate
# sample
# samariumdissolved
# rye(bushels)
# rubidium
# rice(lbs.)
# rhmax
# rhavg
# rh2m(max)
# rh2m
# rh10m(max)
# rh10m
# rh1
# rh(max)
# rh
# residualtototal
# residualp
# relativehumidity.
# relativehumidity
# relativeage
# reflectivity(dbz)
# record
# recharge(m/day)
# realdiel(40cm)
# realdiel(20cm)
# realdiel(10cm)
# rb
# rasterimagedata
# quve
# qust
# quru
# qumo
# quickflow(m3/day)
# qufa
# quartz
# qual
# q(m^3/s)
# profc
# probe
# press
# pred
# precip
# praseodymiumdissolved
# pr
# pp(um/l)
# potasiumppm
# potasium
# poc
# po4p
# po4(mg/l)
# po4
# pmolpog1h1
# pmolbgg1h1
# pmolapg1h1
# plot
# plagioclase
# pita
# pit5temp(c)12cm
# pit4temp(c)11cm
# pit3temp(c)15cm
# pit2temp(c)15cm
# pit1temp(c)15cm
# pit
# piec
# pgch4cg1h1
# perimeter
# pco2atdepth2
# pco2atdepth1
# pco2(ppmv)
# pcc
# pb208(ug/l)
# pb
# particulatep(ug/l)
# particulateorgc(mg/l)
# p;soilpit(p1p20)
# p2o5
# p1mb
# p(μmoll1)
# p(μm)
# p(ug/ml)
# p
# othergrassseeds(bushels)
# othercattle
# other
# orthhoclase
# orp(mv)
# ohm.m
# oh
# oats(bushels)
# o3maximum
# o2pct
# mta
# mod
# mo
# milchcows
# midslp
# mica
# mgo
# mg25(ug/l)
# mg+2(μm)
# mg++(ueq/l)
# mg++(ppm)
# mg(umoll1)
# mg(umoll)
# mg(ug/ml)
# mg(mg/l)
# mg
# method
# metavariscite
# measuredstage
# maximumsoiltemp
# maximumrelativehumidity
# maxht
# maplesugar(lbs.)
# majax
# macroplot
# lvl9
# lvl2
# lutetiumdissolved
# lu
# lpmid
# loi
# litu
# litterfall
# litter
# list
# lidar
# li
# level(mm)
# leaflittermaterial
# ldo%
# ldo
# laz
# layer
# las
# lai;pcc
# lai
# la
# ksatsd
# ksatcv%
# ksat
# ka;vm/km(hr^1)
# k2o
# k+(μm)
# k+(ueq/l)
# k+(ppm)
# k(umoll1)
# k(umoll)
# k(ug/ml)
# k(mg/l)
# k
# irishpotatoes(bushels)
# ip(um/l)
# imagdiel(40cm)
# imagdiel(20cm)
# imagdiel(10cm)
# id
# i
# hydrology
# humidity
# hue
# ht
# hour
# horses
# hops(lbs.)
# holmiumdissolved
# ho
# hmprelativehumidity
# hix
# hhefe(mg/g)
# hhe9be(ug/g)
# hf
# hclp
# haolloysite
# h(mg/l)
# gw2wtemp
# growth(cm)
# group
# grossprimaryproductivity.
# grossprimaryproductivity
# goethite
# gisgeospatialdatabase
# gis
# gibbsite
# geology
# ge
# gd
# gcco2pct
# gcch4ppm
# gageht
# ga
# ftotdoc
# ftot
# foresttype
# foliardelta13c(o/oo)
# flaxseed(bushels)
# flax(lbs.)
# filtersize
# filtered(bareearth)hillshade
# filtered(bareearth)dem
# file1:site
# fieldtech
# fieldlabel
# fi
# fecitrate/ascorbateextractable
# fe57(umoll)
# fe56(ug/l)
# fe54(umoll)
# fe2o3(t)
# fe+3(μm)
# fe(umoll1)
# fe(ug/ml)
# fe(mg/l)
# fe(ii)
# fe
# family
# fagr
# f(μm)
# f(umoll1)
# f(mg/l)
# f
# evtboulder
# europiumdissolved
# eu
# est)
# erbiumdissolved
# er
# eqdiam
# empty
# emi
# ec(us/cm)
# ec(s/m)
# ec
# dysprosiumdissolved
# dy
# dtavg
# dsm
# dryweight
# dop(um/l)
# doc(ppm)
# doc
# do(mgl1)
# do(mg/l)
# do
# dissolvedorgp(ug/l)
# dissolvedorgc(ppm)
# dissolvedorgc(mg/l)
# digitalsurfacemodel
# dickite
# diameter(cm;atrootcollar)
# device
# depthtowatertable
# depthtobt
# depthtobedrock
# depthofsample(cm)
# depthm
# depthcm
# depth(mm)
# depth(cm)
# depth
# dems
# dem
# deltadofh2o
# delta1dofh2o
# delta18oofh2o.
# delta18oofh2o
# delta18o
# delta13cofdic
# degrees2theta
# degc)
# dd/mill
# dbh
# dayofyear
# datesamplecollected(m/d/yy)
# datemeasured
# datecollected(yyyymmdd)
# date(mm/dd/yyyy)
# date(m/d/yy)
# date
# dataloggeridbport
# dataloggeridaport
# d18o/mill
# d18o(permil)
# d181sigma
# d13cco2
# cz36
# cz35
# cz29
# cz28
# cz27
# cz26
# cz25
# cz24
# cz23
# cz22
# cz21
# cz20
# curvature
# cu63(ug/l)
# cu
# cs
# cristobalite
# cr52(ug/l)
# cr
# corr
# co59(ug/l)
# co2pct
# co2flux(μmolm2s1)
# co2flux(umol/m2)
# co2
# co
# cm(right)
# cm(left)
# cm
# cloverseed(bushels)
# cloudcover
# cl(μm)
# cl(umoll1)
# cl(ueq/l)
# cl(ppm)
# cl(mg/l)
# cl
# city
# circularity
# chroma
# cheese(lbs.)
# chargebal
# ceriumdissolved
# ce
# cdom
# cd
# cata
# cashvalueoffarm
# cao
# ca44(ug/l)
# ca43(ug/l)
# ca+2(μm)
# ca++(ueq/l)
# ca(umoll1)
# ca(umoll)
# ca(ug/ml)
# ca(mg/l)
# ca
# c%
# c
# butter(lbs.)
# buckwheat(bushels)
# br(mg/l)
# br
# bp
# block
# bix
# biota
# bi
# betaglucosidaseactivity
# betaglucosidase
# bedrock
# be
# barometricpress(mbar)
# baro
# barley(bushels)
# ba(μmoll1)
# ba(μm)
# ba(ug/ml)
# ba
# averagesoiltemp
# averagerelativehumidity
# averagepfd(moles)
# averagepfd
# averageo3
# averagelai
# augelite
# aspect(degree)
# aspect
# ascii
# as
# alk
# alcitrate/ascorbateextractable
# albite
# al3+
# al2o3
# al27(mg/l)
# al+3(μm)
# al(umoll1)
# al(umoll)
# al(ug/ml)
# al(mg/l)
# al
# airtempmax
# airtempavg
# airtemp(c)2m(max)
# airtemp(c)2m(avg)
# airtemp(c)2.5m(avg)
# airtemp(c)10m(max)
# airtemp(c)10m(avg)
# airtemp(c)
# airtcmax
# airtcavg
# airt
# aggregatestability;file2:site
# age(years).
# agcsum
# ag(μg/l)
# ag
# abspress
# abspres
# 5
# 4
# 3
# 2012dbh(cm)
# 2008dbh(cm)
# 2
# 10bemeteoric
# 10be(10^8atm/g)
# 1.5mo2
# 1.5mh2o
# 1.5mdegc
# 1.5mco2
# 1
# 0.5mo2
# 0.5mh2o
# 0.5mdegc
# 0.5mco2
# .kml
# (waterisotopes)dexcess/mill
# (ggp1:ggp1+ggp2)doc
# (ggp1:ggp1+ggp2)
# (fic'
# %o2atdepth2
# %o2atdepth1
# %diffchargebal
# %c
#
# μgsocg1
# μgeocg1
# δ2hreportablevalue(permil)
# δ2h(‰)
# δ2h(permil)
# δ2h
# δ18oreportablevalue(permil)
# δ18o(‰)
# δ18o
# δ13csoilrespiredco2
# δ13csoc
# δ13ceoc
# βglucosidaseactivity
# zr
# yttriumdissolved
# ytterbiumdissolved
# ymax
# year
# yb
# y
# xrf
# xrd
# xmax
# x
# wtemp
# wsscalavg
# wsmax
# wool(lbs.)
# woodymaterial
# wheat(bushels)
# watertempc
# watertemp(°c)
# watertemp(c)
# watertableraw(mv
# watertable(mmorcm)
# watertable
# waterquality
# waterlevel(ft)
# waterlevel
# waterflux
# waterdepth(cm)
# waterdepth
# w
# vllydpth
# vertical
# vermiculite
# vbat
# valueoforchardproducts(dollars)
# valueoflivestock
# value
# v(μm)
# v
# uva280.
# uva280
# uva254
# utme
# u
# twi
# tsargorodtsevite
# tritium1sigma
# tritium(tu)
# treetype
# treespecies
# treeid
# treegroup
# treegirth1.5m
# treeazimuth
# tree
# trapid
# tpi
# tp(um/l)
# totalzr(mg/g)
# totalppfd
# totalp(ug/l)
# totalp
# totalorgc(mg/l)
# totallittercollected
# totalfe(mg/g)
# totaldissolvedp(ugp/l)
# totaldissolvedp(ug/l)
# totalca(mg/g)
# totalal(mg/g)
# total9be(ug/g)
# total
# tobacco(lbs.)
# tmstamp(yyyymmddhh:mm:ss)
# tmstamp
# tm
# tl
# tio2
# tilepushprobedepth(cm)
# ti(ug/ml)
# ti
# thuliumdissolved
# th
# terbiumdissolved
# tds(mg1)
# tdp(um/l)
# tcdtavg
# tc(mg/l)
# tb
# taup
# ta
# t1c
# t+e(m/day)
# sweetpotatoes(bushels)
# suva280.
# suva280
# surfdegc
# sum+
# sum
# streamwaterchemistry
# stdht
# state
# start
# stagem
# stagediff
# stagecm
# ssurgoid
# ss
# sr(μm)
# sr(umoll1)
# sr(ug/ml)
# sr(mg/l)
# sr
# species
# spc(mscm1)
# solradtot
# solradposs
# soilvwc
# soiltype
# soiltracegases
# soiltexture
# soiltemp(c)22cm
# soiltemp(c)15cm
# soilt
# soils
# soilorder
# soilmoisture.
# soilmoisture(m3/m3)
# soilmoisture(40cm;m3/m3)
# soilmoisture(20cm;m3/m3)
# soilmoisture(10cm;m3/m3)
# soilmoisture
# soilheatflux(w/m^2)15cm
# soilec
# soileb
# soildepth
# soilco2(ppm)
# soilc
# so4s
# so4=(ueq/l)
# so4=(ppm)
# so42(μm)
# so42(umoll1)
# so4(mg/l)
# so4
# smp
# sm
# siteid
# site
# sio2icp(ppm)
# sio2(mg/l)
# sio2
# siicp(ppm)
# si28(ug/l)
# si28(mg/l)
# si(μm)
# si(umoll1)
# si(ug/ml)
# si(mg/l)
# si
# shortaxis
# sheep
# shapefiles
# shadedrelief
# semta
# selai
# seedetailsbelow)
# seedetailbelow)
# se
# scale
# sc
# sb
# sapfluxid
# sapflux
# sapflow
# sampletype
# samplemedium
# samplelabel
# sampleid
# sampledate
# sample
# samariumdissolved
# rye(bushels)
# rubidium
# rice(lbs.)
# rhmax
# rhavg
# rh2m(max)
# rh2m
# rh10m(max)
# rh10m
# rh1
# rh(max)
# rh
# residualtototal
# residualp
# relativehumidity.
# relativehumidity
# relativeage
# reflectivity(dbz)
# record
# recharge(m/day)
# realdiel(40cm)
# realdiel(20cm)
# realdiel(10cm)
# rb
# rasterimagedata
# quve
# qust
# quru
# qumo
# quickflow(m3/day)
# qufa
# quartz
# qual
# q(m^3/s)
# profc
# probe
# press
# pred
# precip
# praseodymiumdissolved
# pr
# pp(um/l)
# potasiumppm
# potasium
# poc
# po4p
# po4(mg/l)
# po4
# pmolpog1h1
# pmolbgg1h1
# pmolapg1h1
# plot
# plagioclase
# pita
# pit5temp(c)12cm
# pit4temp(c)11cm
# pit3temp(c)15cm
# pit2temp(c)15cm
# pit1temp(c)15cm
# pit
# piec
# pgch4cg1h1
# perimeter
# pco2atdepth2
# pco2atdepth1
# pco2(ppmv)
# pcc
# pb208(ug/l)
# pb
# particulatep(ug/l)
# particulateorgc(mg/l)
# p;soilpit(p1p20)
# p2o5
# p1mb
# p(μmoll1)
# p(μm)
# p(ug/ml)
# p
# othergrassseeds(bushels)
# othercattle
# other
# orthhoclase
# orp(mv)
# ohm.m
# oh
# oats(bushels)
# o3maximum
# o2pct
# mta
# mod
# mo
# milchcows
# midslp
# mica
# mgo
# mg25(ug/l)
# mg+2(μm)
# mg++(ueq/l)
# mg++(ppm)
# mg(umoll1)
# mg(umoll)
# mg(ug/ml)
# mg(mg/l)
# mg
# method
# metavariscite
# measuredstage
# maximumsoiltemp
# maximumrelativehumidity
# maxht
# maplesugar(lbs.)
# majax
# macroplot
# lvl9
# lvl2
# lutetiumdissolved
# lu
# lpmid
# loi
# litu
# litterfall
# litter
# list
# lidar
# li
# level(mm)
# leaflittermaterial
# ldo%
# ldo
# laz
# layer
# las
# lai;pcc
# lai
# la
# ksatsd
# ksatcv%
# ksat
# ka;vm/km(hr^1)
# k2o
# k+(μm)
# k+(ueq/l)
# k+(ppm)
# k(umoll1)
# k(umoll)
# k(ug/ml)
# k(mg/l)
# k
# irishpotatoes(bushels)
# ip(um/l)
# imagdiel(40cm)
# imagdiel(20cm)
# imagdiel(10cm)
# id
# i
# hydrology
# humidity
# hue
# ht
# hour
# horses
# hops(lbs.)
# holmiumdissolved
# ho
# hmprelativehumidity
# hix
# hhefe(mg/g)
# hhe9be(ug/g)
# hf
# hclp
# haolloysite
# h(mg/l)
# gw2wtemp
# growth(cm)
# group
# grossprimaryproductivity.
# grossprimaryproductivity
# goethite
# gisgeospatialdatabase
# gis
# gibbsite
# geology
# ge
# gd
# gcco2pct
# gcch4ppm
# gageht
# ga
# ftotdoc
# ftot
# foresttype
# foliardelta13c(o/oo)
# flaxseed(bushels)
# flax(lbs.)
# filtersize
# filtered(bareearth)hillshade
# filtered(bareearth)dem
# file1:site
# fieldtech
# fieldlabel
# fi
# fecitrate/ascorbateextractable
# fe57(umoll)
# fe56(ug/l)
# fe54(umoll)
# fe2o3(t)
# fe+3(μm)
# fe(umoll1)
# fe(ug/ml)
# fe(mg/l)
# fe(ii)
# fe
# family
# fagr
# f(μm)
# f(umoll1)
# f(mg/l)
# f
# evtboulder
# europiumdissolved
# eu
# est)
# erbiumdissolved
# er
# eqdiam
# empty
# emi
# ec(us/cm)
# ec(s/m)
# ec
# dysprosiumdissolved
# dy
# dtavg
# dsm
# dryweight
# dop(um/l)
# doc(ppm)
# doc
# do(mgl1)
# do(mg/l)
# do
# dissolvedorgp(ug/l)
# dissolvedorgc(ppm)
# dissolvedorgc(mg/l)
# digitalsurfacemodel
# dickite
# diameter(cm;atrootcollar)
# device
# depthtowatertable
# depthtobt
# depthtobedrock
# depthofsample(cm)
# depthm
# depthcm
# depth(mm)
# depth(cm)
# depth
# dems
# dem
# deltadofh2o
# delta1dofh2o
# delta18oofh2o.
# delta18oofh2o
# delta18o
# delta13cofdic
# degrees2theta
# degc)
# dd/mill
# dbh
# dayofyear
# datesamplecollected(m/d/yy)
# datemeasured
# datecollected(yyyymmdd)
# date(mm/dd/yyyy)
# date(m/d/yy)
# date
# dataloggeridbport
# dataloggeridaport
# d18o/mill
# d18o(permil)
# d181sigma
# d13cco2
# cz36
# cz35
# cz29
# cz28
# cz27
# cz26
# cz25
# cz24
# cz23
# cz22
# cz21
# cz20
# curvature
# cu63(ug/l)
# cu
# cs
# cristobalite
# cr52(ug/l)
# cr
# corr
# co59(ug/l)
# co2pct
# co2flux(μmolm2s1)
# co2flux(umol/m2)
# co2
# co
# cm(right)
# cm(left)
# cm
# cloverseed(bushels)
# cloudcover
# cl(μm)
# cl(umoll1)
# cl(ueq/l)
# cl(ppm)
# cl(mg/l)
# cl
# city
# circularity
# chroma
# cheese(lbs.)
# chargebal
# ceriumdissolved
# ce
# cdom
# cd
# cata
# cashvalueoffarm
# cao
# ca44(ug/l)
# ca43(ug/l)
# ca+2(μm)
# ca++(ueq/l)
# ca(umoll1)
# ca(umoll)
# ca(ug/ml)
# ca(mg/l)
# ca
# c%
# c
# butter(lbs.)
# buckwheat(bushels)
# br(mg/l)
# br
# bp
# block
# bix
# biota
# bi
# betaglucosidaseactivity
# betaglucosidase
# bedrock
# be
# barometricpress(mbar)
# baro
# barley(bushels)
# ba(μmoll1)
# ba(μm)
# ba(ug/ml)
# ba
# averagesoiltemp
# averagerelativehumidity
# averagepfd(moles)
# averagepfd
# averageo3
# averagelai
# augelite
# aspect(degree)
# aspect
# ascii
# as
# alk
# alcitrate/ascorbateextractable
# albite
# al3+
# al2o3
# al27(mg/l)
# al+3(μm)
# al(umoll1)
# al(umoll)
# al(ug/ml)
# al(mg/l)
# al
# airtempmax
# airtempavg
# airtemp(c)2m(max)
# airtemp(c)2m(avg)
# airtemp(c)2.5m(avg)
# airtemp(c)10m(max)
# airtemp(c)10m(avg)
# airtemp(c)
# airtcmax
# airtcavg
# airt
# aggregatestability;file2:site
# age(years).
# agcsum
# ag(μg/l)
# ag
# abspress
# abspres
# 5
# 4
# 3
# 2012dbh(cm)
# 2008dbh(cm)
# 2
# 10bemeteoric
# 10be(10^8atm/g)
# 1.5mo2
# 1.5mh2o
# 1.5mdegc
# 1.5mco2
# 1
# 0.5mo2
# 0.5mh2o
# 0.5mdegc
# 0.5mco2
# .kml
# (waterisotopes)dexcess/mill
# (ggp1:ggp1+ggp2)doc
# (ggp1:ggp1+ggp2)
# (fic'
# %o2atdepth2
# %o2atdepth1
# %diffchargebal
# %c
#
# μgsocg1
# μgeocg1
# δ2hreportablevalue(permil)
# δ2h(‰)
# δ2h(permil)
# δ2h
# δ18oreportablevalue(permil)
# δ18o(‰)
# δ18o
# δ13csoilrespiredco2
# δ13csoc
# δ13ceoc
# βglucosidaseactivity
# zr
# yttriumdissolved
# ytterbiumdissolved
# ymax
# year
# yb
# y
# xrf
# xrd
# xmax
# x
# wtemp
# wsscalavg
# wsmax
# wool(lbs.)
# woodymaterial
# wheat(bushels)
# watertempc
# watertemp(°c)
# watertemp(c)
# watertableraw(mv
# watertable(mmorcm)
# watertable
# waterquality
# waterlevel(ft)
# waterlevel
# waterflux
# waterdepth(cm)
# waterdepth
# w
# vllydpth
# vertical
# vermiculite
# vbat
# valueoforchardproducts(dollars)
# valueoflivestock
# value
# v(μm)
# v
# uva280.
# uva280
# uva254
# utme
# u
# twi
# tsargorodtsevite
# tritium1sigma
# tritium(tu)
# treetype
# treespecies
# treeid
# treegroup
# treegirth1.5m
# treeazimuth
# tree
# trapid
# tpi
# tp(um/l)
# totalzr(mg/g)
# totalppfd
# totalp(ug/l)
# totalp
# totalorgc(mg/l)
# totallittercollected
# totalfe(mg/g)
# totaldissolvedp(ugp/l)
# totaldissolvedp(ug/l)
# totalca(mg/g)
# totalal(mg/g)
# total9be(ug/g)
# total
# tobacco(lbs.)
# tmstamp(yyyymmddhh:mm:ss)
# tmstamp
# tm
# tl
# tio2
# tilepushprobedepth(cm)
# ti(ug/ml)
# ti
# thuliumdissolved
# th
# terbiumdissolved
# tds(mg1)
# tdp(um/l)
# tcdtavg
# tc(mg/l)
# tb
# taup
# ta
# t1c
# t+e(m/day)
# sweetpotatoes(bushels)
# suva280.
# suva280
# surfdegc
# sum+
# sum
# streamwaterchemistry
# stdht
# state
# start
# stagem
# stagediff
# stagecm
# ssurgoid
# ss
# sr(μm)
# sr(umoll1)
# sr(ug/ml)
# sr(mg/l)
# sr
# species
# spc(mscm1)
# solradtot
# solradposs
# soilvwc
# soiltype
# soiltracegases
# soiltexture
# soiltemp(c)22cm
# soiltemp(c)15cm
# soilt
# soils
# soilorder
# soilmoisture.
# soilmoisture(m3/m3)
# soilmoisture(40cm;m3/m3)
# soilmoisture(20cm;m3/m3)
# soilmoisture(10cm;m3/m3)
# soilmoisture
# soilheatflux(w/m^2)15cm
# soilec
# soileb
# soildepth
# soilco2(ppm)
# soilc
# so4s
# so4=(ueq/l)
# so4=(ppm)
# so42(μm)
# so42(umoll1)
# so4(mg/l)
# so4
# smp
# sm
# siteid
# site
# sio2icp(ppm)
# sio2(mg/l)
# sio2
# siicp(ppm)
# si28(ug/l)
# si28(mg/l)
# si(μm)
# si(umoll1)
# si(ug/ml)
# si(mg/l)
# si
# shortaxis
# sheep
# shapefiles
# shadedrelief
# semta
# selai
# seedetailsbelow)
# seedetailbelow)
# se
# scale
# sc
# sb
# sapfluxid
# sapflux
# sapflow
# sampletype
# samplemedium
# samplelabel
# sampleid
# sampledate
# sample
# samariumdissolved
# rye(bushels)
# rubidium
# rice(lbs.)
# rhmax
# rhavg
# rh2m(max)
# rh2m
# rh10m(max)
# rh10m
# rh1
# rh(max)
# rh
# residualtototal
# residualp
# relativehumidity.
# relativehumidity
# relativeage
# reflectivity(dbz)
# record
# recharge(m/day)
# realdiel(40cm)
# realdiel(20cm)
# realdiel(10cm)
# rb
# rasterimagedata
# quve
# qust
# quru
# qumo
# quickflow(m3/day)
# qufa
# quartz
# qual
# q(m^3/s)
# profc
# probe
# press
# pred
# precip
# praseodymiumdissolved
# pr
# pp(um/l)
# potasiumppm
# potasium
# poc
# po4p
# po4(mg/l)
# po4
# pmolpog1h1
# pmolbgg1h1
# pmolapg1h1
# plot
# plagioclase
# pita
# pit5temp(c)12cm
# pit4temp(c)11cm
# pit3temp(c)15cm
# pit2temp(c)15cm
# pit1temp(c)15cm
# pit
# piec
# pgch4cg1h1
# perimeter
# pco2atdepth2
# pco2atdepth1
# pco2(ppmv)
# pcc
# pb208(ug/l)
# pb
# particulatep(ug/l)
# particulateorgc(mg/l)
# p;soilpit(p1p20)
# p2o5
# p1mb
# p(μmoll1)
# p(μm)
# p(ug/ml)
# p
# othergrassseeds(bushels)
# othercattle
# other
# orthhoclase
# orp(mv)
# ohm.m
# oh
# oats(bushels)
# o3maximum
# o2pct
# mta
# mod
# mo
# milchcows
# midslp
# mica
# mgo
# mg25(ug/l)
# mg+2(μm)
# mg++(ueq/l)
# mg++(ppm)
# mg(umoll1)
# mg(umoll)
# mg(ug/ml)
# mg(mg/l)
# mg
# method
# metavariscite
# measuredstage
# maximumsoiltemp
# maximumrelativehumidity
# maxht
# maplesugar(lbs.)
# majax
# macroplot
# lvl9
# lvl2
# lutetiumdissolved
# lu
# lpmid
# loi
# litu
# litterfall
# litter
# list
# lidar
# li
# level(mm)
# leaflittermaterial
# ldo%
# ldo
# laz
# layer
# las
# lai;pcc
# lai
# la
# ksatsd
# ksatcv%
# ksat
# ka;vm/km(hr^1)
# k2o
# k+(μm)
# k+(ueq/l)
# k+(ppm)
# k(umoll1)
# k(umoll)
# k(ug/ml)
# k(mg/l)
# k
# irishpotatoes(bushels)
# ip(um/l)
# imagdiel(40cm)
# imagdiel(20cm)
# imagdiel(10cm)
# id
# i
# hydrology
# humidity
# hue
# ht
# hour
# horses
# hops(lbs.)
# holmiumdissolved
# ho
# hmprelativehumidity
# hix
# hhefe(mg/g)
# hhe9be(ug/g)
# hf
# hclp
# haolloysite
# h(mg/l)
# gw2wtemp
# growth(cm)
# group
# grossprimaryproductivity.
# grossprimaryproductivity
# goethite
# gisgeospatialdatabase
# gis
# gibbsite
# geology
# ge
# gd
# gcco2pct
# gcch4ppm
# gageht
# ga
# ftotdoc
# ftot
# foresttype
# foliardelta13c(o/oo)
# flaxseed(bushels)
# flax(lbs.)
# filtersize
# filtered(bareearth)hillshade
# filtered(bareearth)dem
# file1:site
# fieldtech
# fieldlabel
# fi
# fecitrate/ascorbateextractable
# fe57(umoll)
# fe56(ug/l)
# fe54(umoll)
# fe2o3(t)
# fe+3(μm)
# fe(umoll1)
# fe(ug/ml)
# fe(mg/l)
# fe(ii)
# fe
# family
# fagr
# f(μm)
# f(umoll1)
# f(mg/l)
# f
# evtboulder
# europiumdissolved
# eu
# est)
# erbiumdissolved
# er
# eqdiam
# empty
# emi
# ec(us/cm)
# ec(s/m)
# ec
# dysprosiumdissolved
# dy
# dtavg
# dsm
# dryweight
# dop(um/l)
# doc(ppm)
# doc
# do(mgl1)
# do(mg/l)
# do
# dissolvedorgp(ug/l)
# dissolvedorgc(ppm)
# dissolvedorgc(mg/l)
# digitalsurfacemodel
# dickite
# diameter(cm;atrootcollar)
# device
# depthtowatertable
# depthtobt
# depthtobedrock
# depthofsample(cm)
# depthm
# depthcm
# depth(mm)
# depth(cm)
# depth
# dems
# dem
# deltadofh2o
# delta1dofh2o
# delta18oofh2o.
# delta18oofh2o
# delta18o
# delta13cofdic
# degrees2theta
# degc)
# dd/mill
# dbh
# dayofyear
# datesamplecollected(m/d/yy)
# datemeasured
# datecollected(yyyymmdd)
# date(mm/dd/yyyy)
# date(m/d/yy)
# date
# dataloggeridbport
# dataloggeridaport
# d18o/mill
# d18o(permil)
# d181sigma
# d13cco2
# cz36
# cz35
# cz29
# cz28
# cz27
# cz26
# cz25
# cz24
# cz23
# cz22
# cz21
# cz20
# curvature
# cu63(ug/l)
# cu
# cs
# cristobalite
# cr52(ug/l)
# cr
# corr
# co59(ug/l)
# co2pct
# co2flux(μmolm2s1)
# co2flux(umol/m2)
# co2
# co
# cm(right)
# cm(left)
# cm
# cloverseed(bushels)
# cloudcover
# cl(μm)
# cl(umoll1)
# cl(ueq/l)
# cl(ppm)
# cl(mg/l)
# cl
# city
# circularity
# chroma
# cheese(lbs.)
# chargebal
# ceriumdissolved
# ce
# cdom
# cd
# cata
# cashvalueoffarm
# cao
# ca44(ug/l)
# ca43(ug/l)
# ca+2(μm)
# ca++(ueq/l)
# ca(umoll1)
# ca(umoll)
# ca(ug/ml)
# ca(mg/l)
# ca
# c%
# c
# butter(lbs.)
# buckwheat(bushels)
# br(mg/l)
# br
# bp
# block
# bix
# biota
# bi
# betaglucosidaseactivity
# betaglucosidase
# bedrock
# be
# barometricpress(mbar)
# baro
# barley(bushels)
# ba(μmoll1)
# ba(μm)
# ba(ug/ml)
# ba
# averagesoiltemp
# averagerelativehumidity
# averagepfd(moles)
# averagepfd
# averageo3
# averagelai
# augelite
# aspect(degree)
# aspect
# ascii
# as
# alk
# alcitrate/ascorbateextractable
# albite
# al3+
# al2o3
# al27(mg/l)
# al+3(μm)
# al(umoll1)
# al(umoll)
# al(ug/ml)
# al(mg/l)
# al
# airtempmax
# airtempavg
# airtemp(c)2m(max)
# airtemp(c)2m(avg)
# airtemp(c)2.5m(avg)
# airtemp(c)10m(max)
# airtemp(c)10m(avg)
# airtemp(c)
# airtcmax
# airtcavg
# airt
# aggregatestability;file2:site
# age(years).
# agcsum
# ag(μg/l)
# ag
# abspress
# abspres
# 5
# 4
# 3
# 2012dbh(cm)
# 2008dbh(cm)
# 2
# 10bemeteoric
# 10be(10^8atm/g)
# 1.5mo2
# 1.5mh2o
# 1.5mdegc
# 1.5mco2
# 1
# 0.5mo2
# 0.5mh2o
# 0.5mdegc
# 0.5mco2
# .kml
# (waterisotopes)dexcess/mill
# (ggp1:ggp1+ggp2)doc
# (ggp1:ggp1+ggp2)
# (fic'
# %o2atdepth2
# %o2atdepth1
# %diffchargebal
# %c
#
# μgsocg1
# μgeocg1
# δ2hreportablevalue(permil)
# δ2h(‰)
# δ2h(permil)
# δ2h
# δ18oreportablevalue(permil)
# δ18o(‰)
# δ18o
# δ13csoilrespiredco2
# δ13csoc
# δ13ceoc
# βglucosidaseactivity
# zr
# yttriumdissolved
# ytterbiumdissolved
# ymax
# year
# yb
# y
# xrf
# xrd
# xmax
# x
# wtemp
# wsscalavg
# wsmax
# wool(lbs.)
# woodymaterial
# wheat(bushels)
# watertempc
# watertemp(°c)
# watertemp(c)
# watertableraw(mv
# watertable(mmorcm)
# watertable
# waterquality
# waterlevel(ft)
# waterlevel
# waterflux
# waterdepth(cm)
# waterdepth
# w
# vllydpth
# vertical
# vermiculite
# vbat
# valueoforchardproducts(dollars)
# valueoflivestock
# value
# v(μm)
# v
# uva280.
# uva280
# uva254
# utme
# u
# twi
# tsargorodtsevite
# tritium1sigma
# tritium(tu)
# treetype
# treespecies
# treeid
# treegroup
# treegirth1.5m
# treeazimuth
# tree
# trapid
# tpi
# tp(um/l)
# totalzr(mg/g)
# totalppfd
# totalp(ug/l)
# totalp
# totalorgc(mg/l)
# totallittercollected
# totalfe(mg/g)
# totaldissolvedp(ugp/l)
# totaldissolvedp(ug/l)
# totalca(mg/g)
# totalal(mg/g)
# total9be(ug/g)
# total
# tobacco(lbs.)
# tmstamp(yyyymmddhh:mm:ss)
# tmstamp
# tm
# tl
# tio2
# tilepushprobedepth(cm)
# ti(ug/ml)
# ti
# thuliumdissolved
# th
# terbiumdissolved
# tds(mg1)
# tdp(um/l)
# tcdtavg
# tc(mg/l)
# tb
# taup
# ta
# t1c
# t+e(m/day)
# sweetpotatoes(bushels)
# suva280.
# suva280
# surfdegc
# sum+
# sum
# streamwaterchemistry
# stdht
# state
# start
# stagem
# stagediff
# stagecm
# ssurgoid
# ss
# sr(μm)
# sr(umoll1)
# sr(ug/ml)
# sr(mg/l)
# sr
# species
# spc(mscm1)
# solradtot
# solradposs
# soilvwc
# soiltype
# soiltracegases
# soiltexture
# soiltemp(c)22cm
# soiltemp(c)15cm
# soilt
# soils
# soilorder
# soilmoisture.
# soilmoisture(m3/m3)
# soilmoisture(40cm;m3/m3)
# soilmoisture(20cm;m3/m3)
# soilmoisture(10cm;m3/m3)
# soilmoisture
# soilheatflux(w/m^2)15cm
# soilec
# soileb
# soildepth
# soilco2(ppm)
# soilc
# so4s
# so4=(ueq/l)
# so4=(ppm)
# so42(μm)
# so42(umoll1)
# so4(mg/l)
# so4
# smp
# sm
# siteid
# site
# sio2icp(ppm)
# sio2(mg/l)
# sio2
# siicp(ppm)
# si28(ug/l)
# si28(mg/l)
# si(μm)
# si(umoll1)
# si(ug/ml)
# si(mg/l)
# si
# shortaxis
# sheep
# shapefiles
# shadedrelief
# semta
# selai
# seedetailsbelow)
# seedetailbelow)
# se
# scale
# sc
# sb
# sapfluxid
# sapflux
# sapflow
# sampletype
# samplemedium
# samplelabel
# sampleid
# sampledate
# sample
# samariumdissolved
# rye(bushels)
# rubidium
# rice(lbs.)
# rhmax
# rhavg
# rh2m(max)
# rh2m
# rh10m(max)
# rh10m
# rh1
# rh(max)
# rh
# residualtototal
# residualp
# relativehumidity.
# relativehumidity
# relativeage
# reflectivity(dbz)
# record
# recharge(m/day)
# realdiel(40cm)
# realdiel(20cm)
# realdiel(10cm)
# rb
# rasterimagedata
# quve
# qust
# quru
# qumo
# quickflow(m3/day)
# qufa
# quartz
# qual
# q(m^3/s)
# profc
# probe
# press
# pred
# precip
# praseodymiumdissolved
# pr
# pp(um/l)
# potasiumppm
# potasium
# poc
# po4p
# po4(mg/l)
# po4
# pmolpog1h1
# pmolbgg1h1
# pmolapg1h1
# plot
# plagioclase
# pita
# pit5temp(c)12cm
# pit4temp(c)11cm
# pit3temp(c)15cm
# pit2temp(c)15cm
# pit1temp(c)15cm
# pit
# piec
# pgch4cg1h1
# perimeter
# pco2atdepth2
# pco2atdepth1
# pco2(ppmv)
# pcc
# pb208(ug/l)
# pb
# particulatep(ug/l)
# particulateorgc(mg/l)
# p;soilpit(p1p20)
# p2o5
# p1mb
# p(μmoll1)
# p(μm)
# p(ug/ml)
# p
# othergrassseeds(bushels)
# othercattle
# other
# orthhoclase
# orp(mv)
# ohm.m
# oh
# oats(bushels)
# o3maximum
# o2pct
# mta
# mod
# mo
# milchcows
# midslp
# mica
# mgo
# mg25(ug/l)
# mg+2(μm)
# mg++(ueq/l)
# mg++(ppm)
# mg(umoll1)
# mg(umoll)
# mg(ug/ml)
# mg(mg/l)
# mg
# method
# metavariscite
# measuredstage
# maximumsoiltemp
# maximumrelativehumidity
# maxht
# maplesugar(lbs.)
# majax
# macroplot
# lvl9
# lvl2
# lutetiumdissolved
# lu
# lpmid
# loi
# litu
# litterfall
# litter
# list
# lidar
# li
# level(mm)
# leaflittermaterial
# ldo%
# ldo
# laz
# layer
# las
# lai;pcc
# lai
# la
# ksatsd
# ksatcv%
# ksat
# ka;vm/km(hr^1)
# k2o
# k+(μm)
# k+(ueq/l)
# k+(ppm)
# k(umoll1)
# k(umoll)
# k(ug/ml)
# k(mg/l)
# k
# irishpotatoes(bushels)
# ip(um/l)
# imagdiel(40cm)
# imagdiel(20cm)
# imagdiel(10cm)
# id
# i
# hydrology
# humidity
# hue
# ht
# hour
# horses
# hops(lbs.)
# holmiumdissolved
# ho
# hmprelativehumidity
# hix
# hhefe(mg/g)
# hhe9be(ug/g)
# hf
# hclp
# haolloysite
# h(mg/l)
# gw2wtemp
# growth(cm)
# group
# grossprimaryproductivity.
# grossprimaryproductivity
# goethite
# gisgeospatialdatabase
# gis
# gibbsite
# geology
# ge
# gd
# gcco2pct
# gcch4ppm
# gageht
# ga
# ftotdoc
# ftot
# foresttype
# foliardelta13c(o/oo)
# flaxseed(bushels)
# flax(lbs.)
# filtersize
# filtered(bareearth)hillshade
# filtered(bareearth)dem
# file1:site
# fieldtech
# fieldlabel
# fi
# fecitrate/ascorbateextractable
# fe57(umoll)
# fe56(ug/l)
# fe54(umoll)
# fe2o3(t)
# fe+3(μm)
# fe(umoll1)
# fe(ug/ml)
# fe(mg/l)
# fe(ii)
# fe
# family
# fagr
# f(μm)
# f(umoll1)
# f(mg/l)
# f
# evtboulder
# europiumdissolved
# eu
# est)
# erbiumdissolved
# er
# eqdiam
# empty
# emi
# ec(us/cm)
# ec(s/m)
# ec
# dysprosiumdissolved
# dy
# dtavg
# dsm
# dryweight
# dop(um/l)
# doc(ppm)
# doc
# do(mgl1)
# do(mg/l)
# do
# dissolvedorgp(ug/l)
# dissolvedorgc(ppm)
# dissolvedorgc(mg/l)
# digitalsurfacemodel
# dickite
# diameter(cm;atrootcollar)
# device
# depthtowatertable
# depthtobt
# depthtobedrock
# depthofsample(cm)
# depthm
# depthcm
# depth(mm)
# depth(cm)
# depth
# dems
# dem
# deltadofh2o
# delta1dofh2o
# delta18oofh2o.
# delta18oofh2o
# delta18o
# delta13cofdic
# degrees2theta
# degc)
# dd/mill
# dbh
# dayofyear
# datesamplecollected(m/d/yy)
# datemeasured
# datecollected(yyyymmdd)
# date(mm/dd/yyyy)
# date(m/d/yy)
# date
# dataloggeridbport
# dataloggeridaport
# d18o/mill
# d18o(permil)
# d181sigma
# d13cco2
# cz36
# cz35
# cz29
# cz28
# cz27
# cz26
# cz25
# cz24
# cz23
# cz22
# cz21
# cz20
# curvature
# cu63(ug/l)
# cu
# cs
# cristobalite
# cr52(ug/l)
# cr
# corr
# co59(ug/l)
# co2pct
# co2flux(μmolm2s1)
# co2flux(umol/m2)
# co2
# co
# cm(right)
# cm(left)
# cm
# cloverseed(bushels)
# cloudcover
# cl(μm)
# cl(umoll1)
# cl(ueq/l)
# cl(ppm)
# cl(mg/l)
# cl
# city
# circularity
# chroma
# cheese(lbs.)
# chargebal
# ceriumdissolved
# ce
# cdom
# cd
# cata
# cashvalueoffarm
# cao
# ca44(ug/l)
# ca43(ug/l)
# ca+2(μm)
# ca++(ueq/l)
# ca(umoll1)
# ca(umoll)
# ca(ug/ml)
# ca(mg/l)
# ca
# c%
# c
# butter(lbs.)
# buckwheat(bushels)
# br(mg/l)
# br
# bp
# block
# bix
# biota
# bi
# betaglucosidaseactivity
# betaglucosidase
# bedrock
# be
# barometricpress(mbar)
# baro
# barley(bushels)
# ba(μmoll1)
# ba(μm)
# ba(ug/ml)
# ba
# averagesoiltemp
# averagerelativehumidity
# averagepfd(moles)
# averagepfd
# averageo3
# averagelai
# augelite
# aspect(degree)
# aspect
# ascii
# as
# alk
# alcitrate/ascorbateextractable
# albite
# al3+
# al2o3
# al27(mg/l)
# al+3(μm)
# al(umoll1)
# al(umoll)
# al(ug/ml)
# al(mg/l)
# al
# airtempmax
# airtempavg
# airtemp(c)2m(max)
# airtemp(c)2m(avg)
# airtemp(c)2.5m(avg)
# airtemp(c)10m(max)
# airtemp(c)10m(avg)
# airtemp(c)
# airtcmax
# airtcavg
# airt
# aggregatestability;file2:site
# age(years).
# agcsum
# ag(μg/l)
# ag
# abspress
# abspres
# 5
# 4
# 3
# 2012dbh(cm)
# 2008dbh(cm)
# 2
# 10bemeteoric
# 10be(10^8atm/g)
# 1.5mo2
# 1.5mh2o
# 1.5mdegc
# 1.5mco2
# 1
# 0.5mo2
# 0.5mh2o
# 0.5mdegc
# 0.5mco2
# .kml
# (waterisotopes)dexcess/mill
# (ggp1:ggp1+ggp2)doc
# (ggp1:ggp1+ggp2)
# (fic'
# %o2atdepth2
# %o2atdepth1
# %diffchargebal
# %c
#
# μgsocg1
# μgeocg1
# δ2hreportablevalue(permil)
# δ2h(‰)
# δ2h(permil)
# δ2h
# δ18oreportablevalue(permil)
# δ18o(‰)
# δ18o
# δ13csoilrespiredco2
# δ13csoc
# δ13ceoc
# βglucosidaseactivity
# zr
# yttriumdissolved
# ytterbiumdissolved
# ymax
# year
# yb
# y
# xrf
# xrd
# xmax
# x
# wtemp
# wsscalavg
# wsmax
# wool(lbs.)
# woodymaterial
# wheat(bushels)
# watertempc
# watertemp(°c)
# watertemp(c)
# watertableraw(mv
# watertable(mmorcm)
# watertable
# waterquality
# waterlevel(ft)
# waterlevel
# waterflux
# waterdepth(cm)
# waterdepth
# w
# vllydpth
# vertical
# vermiculite
# vbat
# valueoforchardproducts(dollars)
# valueoflivestock
# value
# v(μm)
# v
# uva280.
# uva280
# uva254
# utme
# u
# twi
# tsargorodtsevite
# tritium1sigma
# tritium(tu)
# treetype
# treespecies
# treeid
# treegroup
# treegirth1.5m
# treeazimuth
# tree
# trapid
# tpi
# tp(um/l)
# totalzr(mg/g)
# totalppfd
# totalp(ug/l)
# totalp
# totalorgc(mg/l)
# totallittercollected
# totalfe(mg/g)
# totaldissolvedp(ugp/l)
# totaldissolvedp(ug/l)
# totalca(mg/g)
# totalal(mg/g)
# total9be(ug/g)
# total
# tobacco(lbs.)
# tmstamp(yyyymmddhh:mm:ss)
# tmstamp
# tm
# tl
# tio2
# tilepushprobedepth(cm)
# ti(ug/ml)
# ti
# thuliumdissolved
# th
# terbiumdissolved
# tds(mg1)
# tdp(um/l)
# tcdtavg
# tc(mg/l)
# tb
# taup
# ta
# t1c
# t+e(m/day)
# sweetpotatoes(bushels)
# suva280.
# suva280
# surfdegc
# sum+
# sum
# streamwaterchemistry
# stdht
# state
# start
# stagem
# stagediff
# stagecm
# ssurgoid
# ss
# sr(μm)
# sr(umoll1)
# sr(ug/ml)
# sr(mg/l)
# sr
# species
# spc(mscm1)
# solradtot
# solradposs
# soilvwc
# soiltype
# soiltracegases
# soiltexture
# soiltemp(c)22cm
# soiltemp(c)15cm
# soilt
# soils
# soilorder
# soilmoisture.
# soilmoisture(m3/m3)
# soilmoisture(40cm;m3/m3)
# soilmoisture(20cm;m3/m3)
# soilmoisture(10cm;m3/m3)
# soilmoisture
# soilheatflux(w/m^2)15cm
# soilec
# soileb
# soildepth
# soilco2(ppm)
# soilc
# so4s
# so4=(ueq/l)
# so4=(ppm)
# so42(μm)
# so42(umoll1)
# so4(mg/l)
# so4
# smp
# sm
# siteid
# site
# sio2icp(ppm)
# sio2(mg/l)
# sio2
# siicp(ppm)
# si28(ug/l)
# si28(mg/l)
# si(μm)
# si(umoll1)
# si(ug/ml)
# si(mg/l)
# si
# shortaxis
# sheep
# shapefiles
# shadedrelief
# semta
# selai
# seedetailsbelow)
# seedetailbelow)
# se
# scale
# sc
# sb
# sapfluxid
# sapflux
# sapflow
# sampletype
# samplemedium
# samplelabel
# sampleid
# sampledate
# sample
# samariumdissolved
# rye(bushels)
# rubidium
# rice(lbs.)
# rhmax
# rhavg
# rh2m(max)
# rh2m
# rh10m(max)
# rh10m
# rh1
# rh(max)
# rh
# residualtototal
# residualp
# relativehumidity.
# relativehumidity
# relativeage
# reflectivity(dbz)
# record
# recharge(m/day)
# realdiel(40cm)
# realdiel(20cm)
# realdiel(10cm)
# rb
# rasterimagedata
# quve
# qust
# quru
# qumo
# quickflow(m3/day)
# qufa
# quartz
# qual
# q(m^3/s)
# profc
# probe
# press
# pred
# precip
# praseodymiumdissolved
# pr
# pp(um/l)
# potasiumppm
# potasium
# poc
# po4p
# po4(mg/l)
# po4
# pmolpog1h1
# pmolbgg1h1
# pmolapg1h1
# plot
# plagioclase
# pita
# pit5temp(c)12cm
# pit4temp(c)11cm
# pit3temp(c)15cm
# pit2temp(c)15cm
# pit1temp(c)15cm
# pit
# piec
# pgch4cg1h1
# perimeter
# pco2atdepth2
# pco2atdepth1
# pco2(ppmv)
# pcc
# pb208(ug/l)
# pb
# particulatep(ug/l)
# particulateorgc(mg/l)
# p;soilpit(p1p20)
# p2o5
# p1mb
# p(μmoll1)
# p(μm)
# p(ug/ml)
# p
# othergrassseeds(bushels)
# othercattle
# other
# orthhoclase
# orp(mv)
# ohm.m
# oh
# oats(bushels)
# o3maximum
# o2pct
# mta
# mod
# mo
# milchcows
# midslp
# mica
# mgo
# mg25(ug/l)
# mg+2(μm)
# mg++(ueq/l)
# mg++(ppm)
# mg(umoll1)
# mg(umoll)
# mg(ug/ml)
# mg(mg/l)
# mg
# method
# metavariscite
# measuredstage
# maximumsoiltemp
# maximumrelativehumidity
# maxht
# maplesugar(lbs.)
# majax
# macroplot
# lvl9
# lvl2
# lutetiumdissolved
# lu
# lpmid
# loi
# litu
# litterfall
# litter
# list
# lidar
# li
# level(mm)
# leaflittermaterial
# ldo%
# ldo
# laz
# layer
# las
# lai;pcc
# lai
# la
# ksatsd
# ksatcv%
# ksat
# ka;vm/km(hr^1)
# k2o
# k+(μm)
# k+(ueq/l)
# k+(ppm)
# k(umoll1)
# k(umoll)
# k(ug/ml)
# k(mg/l)
# k
# irishpotatoes(bushels)
# ip(um/l)
# imagdiel(40cm)
# imagdiel(20cm)
# imagdiel(10cm)
# id
# i
# hydrology
# humidity
# hue
# ht
# hour
# horses
# hops(lbs.)
# holmiumdissolved
# ho
# hmprelativehumidity
# hix
# hhefe(mg/g)
# hhe9be(ug/g)
# hf
# hclp
# haolloysite
# h(mg/l)
# gw2wtemp
# growth(cm)
# group
# grossprimaryproductivity.
# grossprimaryproductivity
# goethite
# gisgeospatialdatabase
# gis
# gibbsite
# geology
# ge
# gd
# gcco2pct
# gcch4ppm
# gageht
# ga
# ftotdoc
# ftot
# foresttype
# foliardelta13c(o/oo)
# flaxseed(bushels)
# flax(lbs.)
# filtersize
# filtered(bareearth)hillshade
# filtered(bareearth)dem
# file1:site
# fieldtech
# fieldlabel
# fi
# fecitrate/ascorbateextractable
# fe57(umoll)
# fe56(ug/l)
# fe54(umoll)
# fe2o3(t)
# fe+3(μm)
# fe(umoll1)
# fe(ug/ml)
# fe(mg/l)
# fe(ii)
# fe
# family
# fagr
# f(μm)
# f(umoll1)
# f(mg/l)
# f
# evtboulder
# europiumdissolved
# eu
# est)
# erbiumdissolved
# er
# eqdiam
# empty
# emi
# ec(us/cm)
# ec(s/m)
# ec
# dysprosiumdissolved
# dy
# dtavg
# dsm
# dryweight
# dop(um/l)
# doc(ppm)
# doc
# do(mgl1)
# do(mg/l)
# do
# dissolvedorgp(ug/l)
# dissolvedorgc(ppm)
# dissolvedorgc(mg/l)
# digitalsurfacemodel
# dickite
# diameter(cm;atrootcollar)
# device
# depthtowatertable
# depthtobt
# depthtobedrock
# depthofsample(cm)
# depthm
# depthcm
# depth(mm)
# depth(cm)
# depth
# dems
# dem
# deltadofh2o
# delta1dofh2o
# delta18oofh2o.
# delta18oofh2o
# delta18o
# delta13cofdic
# degrees2theta
# degc)
# dd/mill
# dbh
# dayofyear
# datesamplecollected(m/d/yy)
# datemeasured
# datecollected(yyyymmdd)
# date(mm/dd/yyyy)
# date(m/d/yy)
# date
# dataloggeridbport
# dataloggeridaport
# d18o/mill
# d18o(permil)
# d181sigma
# d13cco2
# cz36
# cz35
# cz29
# cz28
# cz27
# cz26
# cz25
# cz24
# cz23
# cz22
# cz21
# cz20
# curvature
# cu63(ug/l)
# cu
# cs
# cristobalite
# cr52(ug/l)
# cr
# corr
# co59(ug/l)
# co2pct
# co2flux(μmolm2s1)
# co2flux(umol/m2)
# co2
# co
# cm(right)
# cm(left)
# cm
# cloverseed(bushels)
# cloudcover
# cl(μm)
# cl(umoll1)
# cl(ueq/l)
# cl(ppm)
# cl(mg/l)
# cl
# city
# circularity
# chroma
# cheese(lbs.)
# chargebal
# ceriumdissolved
# ce
# cdom
# cd
# cata
# cashvalueoffarm
# cao
# ca44(ug/l)
# ca43(ug/l)
# ca+2(μm)
# ca++(ueq/l)
# ca(umoll1)
# ca(umoll)
# ca(ug/ml)
# ca(mg/l)
# ca
# c%
# c
# butter(lbs.)
# buckwheat(bushels)
# br(mg/l)
# br
# bp
# block
# bix
# biota
# bi
# betaglucosidaseactivity
# betaglucosidase
# bedrock
# be
# barometricpress(mbar)
# baro
# barley(bushels)
# ba(μmoll1)
# ba(μm)
# ba(ug/ml)
# ba
# averagesoiltemp
# averagerelativehumidity
# averagepfd(moles)
# averagepfd
# averageo3
# averagelai
# augelite
# aspect(degree)
# aspect
# ascii
# as
# alk
# alcitrate/ascorbateextractable
# albite
# al3+
# al2o3
# al27(mg/l)
# al+3(μm)
# al(umoll1)
# al(umoll)
# al(ug/ml)
# al(mg/l)
# al
# airtempmax
# airtempavg
# airtemp(c)2m(max)
# airtemp(c)2m(avg)
# airtemp(c)2.5m(avg)
# airtemp(c)10m(max)
# airtemp(c)10m(avg)
# airtemp(c)
# airtcmax
# airtcavg
# airt
# aggregatestability;file2:site
# age(years).
# agcsum
# ag(μg/l)
# ag
# abspress
# abspres
# 5
# 4
# 3
# 2012dbh(cm)
# 2008dbh(cm)
# 2
# 10bemeteoric
# 10be(10^8atm/g)
# 1.5mo2
# 1.5mh2o
# 1.5mdegc
# 1.5mco2
# 1
# 0.5mo2
# 0.5mh2o
# 0.5mdegc
# 0.5mco2
# .kml
# (waterisotopes)dexcess/mill
# (ggp1:ggp1+ggp2)doc
# (ggp1:ggp1+ggp2)
# (fic'
# %o2atdepth2
# %o2atdepth1
# %diffchargebal
# %c
#
# μgsocg1
# μgeocg1
# δ2hreportablevalue(permil)
# δ2h(‰)
# δ2h(permil)
# δ2h
# δ18oreportablevalue(permil)
# δ18o(‰)
# δ18o
# δ13csoilrespiredco2
# δ13csoc
# δ13ceoc
# βglucosidaseactivity
# zr
# yttriumdissolved
# ytterbiumdissolved
# ymax
# year
# yb
# y
# xrf
# xrd
# xmax
# x
# wtemp
# wsscalavg
# wsmax
# wool(lbs.)
# woodymaterial
# wheat(bushels)
# watertempc
# watertemp(°c)
# watertemp(c)
# watertableraw(mv
# watertable(mmorcm)
# watertable
# waterquality
# waterlevel(ft)
# waterlevel
# waterflux
# waterdepth(cm)
# waterdepth
# w
# vllydpth
# vertical
# vermiculite
# vbat
# valueoforchardproducts(dollars)
# valueoflivestock
# value
# v(μm)
# v
# uva280.
# uva280
# uva254
# utme
# u
# twi
# tsargorodtsevite
# tritium1sigma
# tritium(tu)
# treetype
# treespecies
# treeid
# treegroup
# treegirth1.5m
# treeazimuth
# tree
# trapid
# tpi
# tp(um/l)
# totalzr(mg/g)
# totalppfd
# totalp(ug/l)
# totalp
# totalorgc(mg/l)
# totallittercollected
# totalfe(mg/g)
# totaldissolvedp(ugp/l)
# totaldissolvedp(ug/l)
# totalca(mg/g)
# totalal(mg/g)
# total9be(ug/g)
# total
# tobacco(lbs.)
# tmstamp(yyyymmddhh:mm:ss)
# tmstamp
# tm
# tl
# tio2
# tilepushprobedepth(cm)
# ti(ug/ml)
# ti
# thuliumdissolved
# th
# terbiumdissolved
# tds(mg1)
# tdp(um/l)
# tcdtavg
# tc(mg/l)
# tb
# taup
# ta
# t1c
# t+e(m/day)
# sweetpotatoes(bushels)
# suva280.
# suva280
# surfdegc
# sum+
# sum
# streamwaterchemistry
# stdht
# state
# start
# stagem
# stagediff
# stagecm
# ssurgoid
# ss
# sr(μm)
# sr(umoll1)
# sr(ug/ml)
# sr(mg/l)
# sr
# species
# spc(mscm1)
# solradtot
# solradposs
# soilvwc
# soiltype
# soiltracegases
# soiltexture
# soiltemp(c)22cm
# soiltemp(c)15cm
# soilt
# soils
# soilorder
# soilmoisture.
# soilmoisture(m3/m3)
# soilmoisture(40cm;m3/m3)
# soilmoisture(20cm;m3/m3)
# soilmoisture(10cm;m3/m3)
# soilmoisture
# soilheatflux(w/m^2)15cm
# soilec
# soileb
# soildepth
# soilco2(ppm)
# soilc
# so4s
# so4=(ueq/l)
# so4=(ppm)
# so42(μm)
# so42(umoll1)
# so4(mg/l)
# so4
# smp
# sm
# siteid
# site
# sio2icp(ppm)
# sio2(mg/l)
# sio2
# siicp(ppm)
# si28(ug/l)
# si28(mg/l)
# si(μm)
# si(umoll1)
# si(ug/ml)
# si(mg/l)
# si
# shortaxis
# sheep
# shapefiles
# shadedrelief
# semta
# selai
# seedetailsbelow)
# seedetailbelow)
# se
# scale
# sc
# sb
# sapfluxid
# sapflux
# sapflow
# sampletype
# samplemedium
# samplelabel
# sampleid
# sampledate
# sample
# samariumdissolved
# rye(bushels)
# rubidium
# rice(lbs.)
# rhmax
# rhavg
# rh2m(max)
# rh2m
# rh10m(max)
# rh10m
# rh1
# rh(max)
# rh
# residualtototal
# residualp
# relativehumidity.
# relativehumidity
# relativeage
# reflectivity(dbz)
# record
# recharge(m/day)
# realdiel(40cm)
# realdiel(20cm)
# realdiel(10cm)
# rb
# rasterimagedata
# quve
# qust
# quru
# qumo
# quickflow(m3/day)
# qufa
# quartz
# qual
# q(m^3/s)
# profc
# probe
# press
# pred
# precip
# praseodymiumdissolved
# pr
# pp(um/l)
# potasiumppm
# potasium
# poc
# po4p
# po4(mg/l)
# po4
# pmolpog1h1
# pmolbgg1h1
# pmolapg1h1
# plot
# plagioclase
# pita
# pit5temp(c)12cm
# pit4temp(c)11cm
# pit3temp(c)15cm
# pit2temp(c)15cm
# pit1temp(c)15cm
# pit
# piec
# pgch4cg1h1
# perimeter
# pco2atdepth2
# pco2atdepth1
# pco2(ppmv)
# pcc
# pb208(ug/l)
# pb
# particulatep(ug/l)
# particulateorgc(mg/l)
# p;soilpit(p1p20)
# p2o5
# p1mb
# p(μmoll1)
# p(μm)
# p(ug/ml)
# p
# othergrassseeds(bushels)
# othercattle
# other
# orthhoclase
# orp(mv)
# ohm.m
# oh
# oats(bushels)
# o3maximum
# o2pct
# mta
# mod
# mo
# milchcows
# midslp
# mica
# mgo
# mg25(ug/l)
# mg+2(μm)
# mg++(ueq/l)
# mg++(ppm)
# mg(umoll1)
# mg(umoll)
# mg(ug/ml)
# mg(mg/l)
# mg
# method
# metavariscite
# measuredstage
# maximumsoiltemp
# maximumrelativehumidity
# maxht
# maplesugar(lbs.)
# majax
# macroplot
# lvl9
# lvl2
# lutetiumdissolved
# lu
# lpmid
# loi
# litu
# litterfall
# litter
# list
# lidar
# li
# level(mm)
# leaflittermaterial
# ldo%
# ldo
# laz
# layer
# las
# lai;pcc
# lai
# la
# ksatsd
# ksatcv%
# ksat
# ka;vm/km(hr^1)
# k2o
# k+(μm)
# k+(ueq/l)
# k+(ppm)
# k(umoll1)
# k(umoll)
# k(ug/ml)
# k(mg/l)
# k
# irishpotatoes(bushels)
# ip(um/l)
# imagdiel(40cm)
# imagdiel(20cm)
# imagdiel(10cm)
# id
# i
# hydrology
# humidity
# hue
# ht
# hour
# horses
# hops(lbs.)
# holmiumdissolved
# ho
# hmprelativehumidity
# hix
# hhefe(mg/g)
# hhe9be(ug/g)
# hf
# hclp
# haolloysite
# h(mg/l)
# gw2wtemp
# growth(cm)
# group
# grossprimaryproductivity.
# grossprimaryproductivity
# goethite
# gisgeospatialdatabase
# gis
# gibbsite
# geology
# ge
# gd
# gcco2pct
# gcch4ppm
# gageht
# ga
# ftotdoc
# ftot
# foresttype
# foliardelta13c(o/oo)
# flaxseed(bushels)
# flax(lbs.)
# filtersize
# filtered(bareearth)hillshade
# filtered(bareearth)dem
# file1:site
# fieldtech
# fieldlabel
# fi
# fecitrate/ascorbateextractable
# fe57(umoll)
# fe56(ug/l)
# fe54(umoll)
# fe2o3(t)
# fe+3(μm)
# fe(umoll1)
# fe(ug/ml)
# fe(mg/l)
# fe(ii)
# fe
# family
# fagr
# f(μm)
# f(umoll1)
# f(mg/l)
# f
# evtboulder
# europiumdissolved
# eu
# est)
# erbiumdissolved
# er
# eqdiam
# empty
# emi
# ec(us/cm)
# ec(s/m)
# ec
# dysprosiumdissolved
# dy
# dtavg
# dsm
# dryweight
# dop(um/l)
# doc(ppm)
# doc
# do(mgl1)
# do(mg/l)
# do
# dissolvedorgp(ug/l)
# dissolvedorgc(ppm)
# dissolvedorgc(mg/l)
# digitalsurfacemodel
# dickite
# diameter(cm;atrootcollar)
# device
# depthtowatertable
# depthtobt
# depthtobedrock
# depthofsample(cm)
# depthm
# depthcm
# depth(mm)
# depth(cm)
# depth
# dems
# dem
# deltadofh2o
# delta1dofh2o
# delta18oofh2o.
# delta18oofh2o
# delta18o
# delta13cofdic
# degrees2theta
# degc)
# dd/mill
# dbh
# dayofyear
# datesamplecollected(m/d/yy)
# datemeasured
# datecollected(yyyymmdd)
# date(mm/dd/yyyy)
# date(m/d/yy)
# date
# dataloggeridbport
# dataloggeridaport
# d18o/mill
# d18o(permil)
# d181sigma
# d13cco2
# cz36
# cz35
# cz29
# cz28
# cz27
# cz26
# cz25
# cz24
# cz23
# cz22
# cz21
# cz20
# curvature
# cu63(ug/l)
# cu
# cs
# cristobalite
# cr52(ug/l)
# cr
# corr
# co59(ug/l)
# co2pct
# co2flux(μmolm2s1)
# co2flux(umol/m2)
# co2
# co
# cm(right)
# cm(left)
# cm
# cloverseed(bushels)
# cloudcover
# cl(μm)
# cl(umoll1)
# cl(ueq/l)
# cl(ppm)
# cl(mg/l)
# cl
# city
# circularity
# chroma
# cheese(lbs.)
# chargebal
# ceriumdissolved
# ce
# cdom
# cd
# cata
# cashvalueoffarm
# cao
# ca44(ug/l)
# ca43(ug/l)
# ca+2(μm)
# ca++(ueq/l)
# ca(umoll1)
# ca(umoll)
# ca(ug/ml)
# ca(mg/l)
# ca
# c%
# c
# butter(lbs.)
# buckwheat(bushels)
# br(mg/l)
# br
# bp
# block
# bix
# biota
# bi
# betaglucosidaseactivity
# betaglucosidase
# bedrock
# be
# barometricpress(mbar)
# baro
# barley(bushels)
# ba(μmoll1)
# ba(μm)
# ba(ug/ml)
# ba
# averagesoiltemp
# averagerelativehumidity
# averagepfd(moles)
# averagepfd
# averageo3
# averagelai
# augelite
# aspect(degree)
# aspect
# ascii
# as
# alk
# alcitrate/ascorbateextractable
# albite
# al3+
# al2o3
# al27(mg/l)
# al+3(μm)
# al(umoll1)
# al(umoll)
# al(ug/ml)
# al(mg/l)
# al
# airtempmax
# airtempavg
# airtemp(c)2m(max)
# airtemp(c)2m(avg)
# airtemp(c)2.5m(avg)
# airtemp(c)10m(max)
# airtemp(c)10m(avg)
# airtemp(c)
# airtcmax
# airtcavg
# airt
# aggregatestability;file2:site
# age(years).
# agcsum
# ag(μg/l)
# ag
# abspress
# abspres
# 5
# 4
# 3
# 2012dbh(cm)
# 2008dbh(cm)
# 2
# 10bemeteoric
# 10be(10^8atm/g)
# 1.5mo2
# 1.5mh2o
# 1.5mdegc
# 1.5mco2
# 1
# 0.5mo2
# 0.5mh2o
# 0.5mdegc
# 0.5mco2
# .kml
# (waterisotopes)dexcess/mill
# (ggp1:ggp1+ggp2)doc
# (ggp1:ggp1+ggp2)
# (fic'
# %o2atdepth2
# %o2atdepth1
# %diffchargebal
# %c
#
# μgsocg1
# μgeocg1
# δ2hreportablevalue(permil)
# δ2h(‰)
# δ2h(permil)
# δ2h
# δ18oreportablevalue(permil)
# δ18o(‰)
# δ18o
# δ13csoilrespiredco2
# δ13csoc
# δ13ceoc
# βglucosidaseactivity
# zr
# yttriumdissolved
# ytterbiumdissolved
# ymax
# year
# yb
# y
# xrf
# xrd
# xmax
# x
# wtemp
# wsscalavg
# wsmax
# wool(lbs.)
# woodymaterial
# wheat(bushels)
# watertempc
# watertemp(°c)
# watertemp(c)
# watertableraw(mv
# watertable(mmorcm)
# watertable
# waterquality
# waterlevel(ft)
# waterlevel
# waterflux
# waterdepth(cm)
# waterdepth
# w
# vllydpth
# vertical
# vermiculite
# vbat
# valueoforchardproducts(dollars)
# valueoflivestock
# value
# v(μm)
# v
# uva280.
# uva280
# uva254
# utme
# u
# twi
# tsargorodtsevite
# tritium1sigma
# tritium(tu)
# treetype
# treespecies
# treeid
# treegroup
# treegirth1.5m
# treeazimuth
# tree
# trapid
# tpi
# tp(um/l)
# totalzr(mg/g)
# totalppfd
# totalp(ug/l)
# totalp
# totalorgc(mg/l)
# totallittercollected
# totalfe(mg/g)
# totaldissolvedp(ugp/l)
# totaldissolvedp(ug/l)
# totalca(mg/g)
# totalal(mg/g)
# total9be(ug/g)
# total
# tobacco(lbs.)
# tmstamp(yyyymmddhh:mm:ss)
# tmstamp
# tm
# tl
# tio2
# tilepushprobedepth(cm)
# ti(ug/ml)
# ti
# thuliumdissolved
# th
# terbiumdissolved
# tds(mg1)
# tdp(um/l)
# tcdtavg
# tc(mg/l)
# tb
# taup
# ta
# t1c
# t+e(m/day)
# sweetpotatoes(bushels)
# suva280.
# suva280
# surfdegc
# sum+
# sum
# streamwaterchemistry
# stdht
# state
# start
# stagem
# stagediff
# stagecm
# ssurgoid
# ss
# sr(μm)
# sr(umoll1)
# sr(ug/ml)
# sr(mg/l)
# sr
# species
# spc(mscm1)
# solradtot
# solradposs
# soilvwc
# soiltype
# soiltracegases
# soiltexture
# soiltemp(c)22cm
# soiltemp(c)15cm
# soilt
# soils
# soilorder
# soilmoisture.
# soilmoisture(m3/m3)
# soilmoisture(40cm;m3/m3)
# soilmoisture(20cm;m3/m3)
# soilmoisture(10cm;m3/m3)
# soilmoisture
# soilheatflux(w/m^2)15cm
# soilec
# soileb
# soildepth
# soilco2(ppm)
# soilc
# so4s
# so4=(ueq/l)
# so4=(ppm)
# so42(μm)
# so42(umoll1)
# so4(mg/l)
# so4
# smp
# sm
# siteid
# site
# sio2icp(ppm)
# sio2(mg/l)
# sio2
# siicp(ppm)
# si28(ug/l)
# si28(mg/l)
# si(μm)
# si(umoll1)
# si(ug/ml)
# si(mg/l)
# si
# shortaxis
# sheep
# shapefiles
# shadedrelief
# semta
# selai
# seedetailsbelow)
# seedetailbelow)
# se
# scale
# sc
# sb
# sapfluxid
# sapflux
# sapflow
# sampletype
# samplemedium
# samplelabel
# sampleid
# sampledate
# sample
# samariumdissolved
# rye(bushels)
# rubidium
# rice(lbs.)
# rhmax
# rhavg
# rh2m(max)
# rh2m
# rh10m(max)
# rh10m
# rh1
# rh(max)
# rh
# residualtototal
# residualp
# relativehumidity.
# relativehumidity
# relativeage
# reflectivity(dbz)
# record
# recharge(m/day)
# realdiel(40cm)
# realdiel(20cm)
# realdiel(10cm)
# rb
# rasterimagedata
# quve
# qust
# quru
# qumo
# quickflow(m3/day)
# qufa
# quartz
# qual
# q(m^3/s)
# profc
# probe
# press
# pred
# precip
# praseodymiumdissolved
# pr
# pp(um/l)
# potasiumppm
# potasium
# poc
# po4p
# po4(mg/l)
# po4
# pmolpog1h1
# pmolbgg1h1
# pmolapg1h1
# plot
# plagioclase
# pita
# pit5temp(c)12cm
# pit4temp(c)11cm
# pit3temp(c)15cm
# pit2temp(c)15cm
# pit1temp(c)15cm
# pit
# piec
# pgch4cg1h1
# perimeter
# pco2atdepth2
# pco2atdepth1
# pco2(ppmv)
# pcc
# pb208(ug/l)
# pb
# particulatep(ug/l)
# particulateorgc(mg/l)
# p;soilpit(p1p20)
# p2o5
# p1mb
# p(μmoll1)
# p(μm)
# p(ug/ml)
# p
# othergrassseeds(bushels)
# othercattle
# other
# orthhoclase
# orp(mv)
# ohm.m
# oh
# oats(bushels)
# o3maximum
# o2pct
# mta
# mod
# mo
# milchcows
# midslp
# mica
# mgo
# mg25(ug/l)
# mg+2(μm)
# mg++(ueq/l)
# mg++(ppm)
# mg(umoll1)
# mg(umoll)
# mg(ug/ml)
# mg(mg/l)
# mg
# method
# metavariscite
# measuredstage
# maximumsoiltemp
# maximumrelativehumidity
# maxht
# maplesugar(lbs.)
# majax
# macroplot
# lvl9
# lvl2
# lutetiumdissolved
# lu
# lpmid
# loi
# litu
# litterfall
# litter
# list
# lidar
# li
# level(mm)
# leaflittermaterial
# ldo%
# ldo
# laz
# layer
# las
# lai;pcc
# lai
# la
# ksatsd
# ksatcv%
# ksat
# ka;vm/km(hr^1)
# k2o
# k+(μm)
# k+(ueq/l)
# k+(ppm)
# k(umoll1)
# k(umoll)
# k(ug/ml)
# k(mg/l)
# k
# irishpotatoes(bushels)
# ip(um/l)
# imagdiel(40cm)
# imagdiel(20cm)
# imagdiel(10cm)
# id
# i
# hydrology
# humidity
# hue
# ht
# hour
# horses
# hops(lbs.)
# holmiumdissolved
# ho
# hmprelativehumidity
# hix
# hhefe(mg/g)
# hhe9be(ug/g)
# hf
# hclp
# haolloysite
# h(mg/l)
# gw2wtemp
# growth(cm)
# group
# grossprimaryproductivity.
# grossprimaryproductivity
# goethite
# gisgeospatialdatabase
# gis
# gibbsite
# geology
# ge
# gd
# gcco2pct
# gcch4ppm
# gageht
# ga
# ftotdoc
# ftot
# foresttype
# foliardelta13c(o/oo)
# flaxseed(bushels)
# flax(lbs.)
# filtersize
# filtered(bareearth)hillshade
# filtered(bareearth)dem
# file1:site
# fieldtech
# fieldlabel
# fi
# fecitrate/ascorbateextractable
# fe57(umoll)
# fe56(ug/l)
# fe54(umoll)
# fe2o3(t)
# fe+3(μm)
# fe(umoll1)
# fe(ug/ml)
# fe(mg/l)
# fe(ii)
# fe
# family
# fagr
# f(μm)
# f(umoll1)
# f(mg/l)
# f
# evtboulder
# europiumdissolved
# eu
# est)
# erbiumdissolved
# er
# eqdiam
# empty
# emi
# ec(us/cm)
# ec(s/m)
# ec
# dysprosiumdissolved
# dy
# dtavg
# dsm
# dryweight
# dop(um/l)
# doc(ppm)
# doc
# do(mgl1)
# do(mg/l)
# do
# dissolvedorgp(ug/l)
# dissolvedorgc(ppm)
# dissolvedorgc(mg/l)
# digitalsurfacemodel
# dickite
# diameter(cm;atrootcollar)
# device
# depthtowatertable
# depthtobt
# depthtobedrock
# depthofsample(cm)
# depthm
# depthcm
# depth(mm)
# depth(cm)
# depth
# dems
# dem
# deltadofh2o
# delta1dofh2o
# delta18oofh2o.
# delta18oofh2o
# delta18o
# delta13cofdic
# degrees2theta
# degc)
# dd/mill
# dbh
# dayofyear
# datesamplecollected(m/d/yy)
# datemeasured
# datecollected(yyyymmdd)
# date(mm/dd/yyyy)
# date(m/d/yy)
# date
# dataloggeridbport
# dataloggeridaport
# d18o/mill
# d18o(permil)
# d181sigma
# d13cco2
# cz36
# cz35
# cz29
# cz28
# cz27
# cz26
# cz25
# cz24
# cz23
# cz22
# cz21
# cz20
# curvature
# cu63(ug/l)
# cu
# cs
# cristobalite
# cr52(ug/l)
# cr
# corr
# co59(ug/l)
# co2pct
# co2flux(μmolm2s1)
# co2flux(umol/m2)
# co2
# co
# cm(right)
# cm(left)
# cm
# cloverseed(bushels)
# cloudcover
# cl(μm)
# cl(umoll1)
# cl(ueq/l)
# cl(ppm)
# cl(mg/l)
# cl
# city
# circularity
# chroma
# cheese(lbs.)
# chargebal
# ceriumdissolved
# ce
# cdom
# cd
# cata
# cashvalueoffarm
# cao
# ca44(ug/l)
# ca43(ug/l)
# ca+2(μm)
# ca++(ueq/l)
# ca(umoll1)
# ca(umoll)
# ca(ug/ml)
# ca(mg/l)
# ca
# c%
# c
# butter(lbs.)
# buckwheat(bushels)
# br(mg/l)
# br
# bp
# block
# bix
# biota
# bi
# betaglucosidaseactivity
# betaglucosidase
# bedrock
# be
# barometricpress(mbar)
# baro
# barley(bushels)
# ba(μmoll1)
# ba(μm)
# ba(ug/ml)
# ba
# averagesoiltemp
# averagerelativehumidity
# averagepfd(moles)
# averagepfd
# averageo3
# averagelai
# augelite
# aspect(degree)
# aspect
# ascii
# as
# alk
# alcitrate/ascorbateextractable
# albite
# al3+
# al2o3
# al27(mg/l)
# al+3(μm)
# al(umoll1)
# al(umoll)
# al(ug/ml)
# al(mg/l)
# al
# airtempmax
# airtempavg
# airtemp(c)2m(max)
# airtemp(c)2m(avg)
# airtemp(c)2.5m(avg)
# airtemp(c)10m(max)
# airtemp(c)10m(avg)
# airtemp(c)
# airtcmax
# airtcavg
# airt
# aggregatestability;file2:site
# age(years).
# agcsum
# ag(μg/l)
# ag
# abspress
# abspres
# 5
# 4
# 3
# 2012dbh(cm)
# 2008dbh(cm)
# 2
# 10bemeteoric
# 10be(10^8atm/g)
# 1.5mo2
# 1.5mh2o
# 1.5mdegc
# 1.5mco2
# 1
# 0.5mo2
# 0.5mh2o
# 0.5mdegc
# 0.5mco2
# .kml
# (waterisotopes)dexcess/mill
# (ggp1:ggp1+ggp2)doc
# (ggp1:ggp1+ggp2)
# (fic'
# %o2atdepth2
# %o2atdepth1
# %diffchargebal
# %c
#
# μgsocg1
# μgeocg1
# δ2hreportablevalue(permil)
# δ2h(‰)
# δ2h(permil)
# δ2h
# δ18oreportablevalue(permil)
# δ18o(‰)
# δ18o
# δ13csoilrespiredco2
# δ13csoc
# δ13ceoc
# βglucosidaseactivity
# zr
# yttriumdissolved
# ytterbiumdissolved
# ymax
# year
# yb
# y
# xrf
# xrd
# xmax
# x
# wtemp
# wsscalavg
# wsmax
# wool(lbs.)
# woodymaterial
# wheat(bushels)
# watertempc
# watertemp(°c)
# watertemp(c)
# watertableraw(mv
# watertable(mmorcm)
# watertable
# waterquality
# waterlevel(ft)
# waterlevel
# waterflux
# waterdepth(cm)
# waterdepth
# w
# vllydpth
# vertical
# vermiculite
# vbat
# valueoforchardproducts(dollars)
# valueoflivestock
# value
# v(μm)
# v
# uva280.
# uva280
# uva254
# utme
# u
# twi
# tsargorodtsevite
# tritium1sigma
# tritium(tu)
# treetype
# treespecies
# treeid
# treegroup
# treegirth1.5m
# treeazimuth
# tree
# trapid
# tpi
# tp(um/l)
# totalzr(mg/g)
# totalppfd
# totalp(ug/l)
# totalp
# totalorgc(mg/l)
# totallittercollected
# totalfe(mg/g)
# totaldissolvedp(ugp/l)
# totaldissolvedp(ug/l)
# totalca(mg/g)
# totalal(mg/g)
# total9be(ug/g)
# total
# tobacco(lbs.)
# tmstamp(yyyymmddhh:mm:ss)
# tmstamp
# tm
# tl
# tio2
# tilepushprobedepth(cm)
# ti(ug/ml)
# ti
# thuliumdissolved
# th
# terbiumdissolved
# tds(mg1)
# tdp(um/l)
# tcdtavg
# tc(mg/l)
# tb
# taup
# ta
# t1c
# t+e(m/day)
# sweetpotatoes(bushels)
# suva280.
# suva280
# surfdegc
# sum+
# sum
# streamwaterchemistry
# stdht
# state
# start
# stagem
# stagediff
# stagecm
# ssurgoid
# ss
# sr(μm)
# sr(umoll1)
# sr(ug/ml)
# sr(mg/l)
# sr
# species
# spc(mscm1)
# solradtot
# solradposs
# soilvwc
# soiltype
# soiltracegases
# soiltexture
# soiltemp(c)22cm
# soiltemp(c)15cm
# soilt
# soils
# soilorder
# soilmoisture.
# soilmoisture(m3/m3)
# soilmoisture(40cm;m3/m3)
# soilmoisture(20cm;m3/m3)
# soilmoisture(10cm;m3/m3)
# soilmoisture
# soilheatflux(w/m^2)15cm
# soilec
# soileb
# soildepth
# soilco2(ppm)
# soilc
# so4s
# so4=(ueq/l)
# so4=(ppm)
# so42(μm)
# so42(umoll1)
# so4(mg/l)
# so4
# smp
# sm
# siteid
# site
# sio2icp(ppm)
# sio2(mg/l)
# sio2
# siicp(ppm)
# si28(ug/l)
# si28(mg/l)
# si(μm)
# si(umoll1)
# si(ug/ml)
# si(mg/l)
# si
# shortaxis
# sheep
# shapefiles
# shadedrelief
# semta
# selai
# seedetailsbelow)
# seedetailbelow)
# se
# scale
# sc
# sb
# sapfluxid
# sapflux
# sapflow
# sampletype
# samplemedium
# samplelabel
# sampleid
# sampledate
# sample
# samariumdissolved
# rye(bushels)
# rubidium
# rice(lbs.)
# rhmax
# rhavg
# rh2m(max)
# rh2m
# rh10m(max)
# rh10m
# rh1
# rh(max)
# rh
# residualtototal
# residualp
# relativehumidity.
# relativehumidity
# relativeage
# reflectivity(dbz)
# record
# recharge(m/day)
# realdiel(40cm)
# realdiel(20cm)
# realdiel(10cm)
# rb
# rasterimagedata
# quve
# qust
# quru
# qumo
# quickflow(m3/day)
# qufa
# quartz
# qual
# q(m^3/s)
# profc
# probe
# press
# pred
# precip
# praseodymiumdissolved
# pr
# pp(um/l)
# potasiumppm
# potasium
# poc
# po4p
# po4(mg/l)
# po4
# pmolpog1h1
# pmolbgg1h1
# pmolapg1h1
# plot
# plagioclase
# pita
# pit5temp(c)12cm
# pit4temp(c)11cm
# pit3temp(c)15cm
# pit2temp(c)15cm
# pit1temp(c)15cm
# pit
# piec
# pgch4cg1h1
# perimeter
# pco2atdepth2
# pco2atdepth1
# pco2(ppmv)
# pcc
# pb208(ug/l)
# pb
# particulatep(ug/l)
# particulateorgc(mg/l)
# p;soilpit(p1p20)
# p2o5
# p1mb
# p(μmoll1)
# p(μm)
# p(ug/ml)
# p
# othergrassseeds(bushels)
# othercattle
# other
# orthhoclase
# orp(mv)
# ohm.m
# oh
# oats(bushels)
# o3maximum
# o2pct
# mta
# mod
# mo
# milchcows
# midslp
# mica
# mgo
# mg25(ug/l)
# mg+2(μm)
# mg++(ueq/l)
# mg++(ppm)
# mg(umoll1)
# mg(umoll)
# mg(ug/ml)
# mg(mg/l)
# mg
# method
# metavariscite
# measuredstage
# maximumsoiltemp
# maximumrelativehumidity
# maxht
# maplesugar(lbs.)
# majax
# macroplot
# lvl9
# lvl2
# lutetiumdissolved
# lu
# lpmid
# loi
# litu
# litterfall
# litter
# list
# lidar
# li
# level(mm)
# leaflittermaterial
# ldo%
# ldo
# laz
# layer
# las
# lai;pcc
# lai
# la
# ksatsd
# ksatcv%
# ksat
# ka;vm/km(hr^1)
# k2o
# k+(μm)
# k+(ueq/l)
# k+(ppm)
# k(umoll1)
# k(umoll)
# k(ug/ml)
# k(mg/l)
# k
# irishpotatoes(bushels)
# ip(um/l)
# imagdiel(40cm)
# imagdiel(20cm)
# imagdiel(10cm)
# id
# i
# hydrology
# humidity
# hue
# ht
# hour
# horses
# hops(lbs.)
# holmiumdissolved
# ho
# hmprelativehumidity
# hix
# hhefe(mg/g)
# hhe9be(ug/g)
# hf
# hclp
# haolloysite
# h(mg/l)
# gw2wtemp
# growth(cm)
# group
# grossprimaryproductivity.
# grossprimaryproductivity
# goethite
# gisgeospatialdatabase
# gis
# gibbsite
# geology
# ge
# gd
# gcco2pct
# gcch4ppm
# gageht
# ga
# ftotdoc
# ftot
# foresttype
# foliardelta13c(o/oo)
# flaxseed(bushels)
# flax(lbs.)
# filtersize
# filtered(bareearth)hillshade
# filtered(bareearth)dem
# file1:site
# fieldtech
# fieldlabel
# fi
# fecitrate/ascorbateextractable
# fe57(umoll)
# fe56(ug/l)
# fe54(umoll)
# fe2o3(t)
# fe+3(μm)
# fe(umoll1)
# fe(ug/ml)
# fe(mg/l)
# fe(ii)
# fe
# family
# fagr
# f(μm)
# f(umoll1)
# f(mg/l)
# f
# evtboulder
# europiumdissolved
# eu
# est)
# erbiumdissolved
# er
# eqdiam
# empty
# emi
# ec(us/cm)
# ec(s/m)
# ec
# dysprosiumdissolved
# dy
# dtavg
# dsm
# dryweight
# dop(um/l)
# doc(ppm)
# doc
# do(mgl1)
# do(mg/l)
# do
# dissolvedorgp(ug/l)
# dissolvedorgc(ppm)
# dissolvedorgc(mg/l)
# digitalsurfacemodel
# dickite
# diameter(cm;atrootcollar)
# device
# depthtowatertable
# depthtobt
# depthtobedrock
# depthofsample(cm)
# depthm
# depthcm
# depth(mm)
# depth(cm)
# depth
# dems
# dem
# deltadofh2o
# delta1dofh2o
# delta18oofh2o.
# delta18oofh2o
# delta18o
# delta13cofdic
# degrees2theta
# degc)
# dd/mill
# dbh
# dayofyear
# datesamplecollected(m/d/yy)
# datemeasured
# datecollected(yyyymmdd)
# date(mm/dd/yyyy)
# date(m/d/yy)
# date
# dataloggeridbport
# dataloggeridaport
# d18o/mill
# d18o(permil)
# d181sigma
# d13cco2
# cz36
# cz35
# cz29
# cz28
# cz27
# cz26
# cz25
# cz24
# cz23
# cz22
# cz21
# cz20
# curvature
# cu63(ug/l)
# cu
# cs
# cristobalite
# cr52(ug/l)
# cr
# corr
# co59(ug/l)
# co2pct
# co2flux(μmolm2s1)
# ...
# pmolapg1h1
# plot
# plagioclase
# pita
# pit5temp(c)12cm
# pit4temp(c)11cm
# pit3temp(c)15cm
# pit2temp(c)15cm
# pit1temp(c)15cm
# pit
# piec
# pgch4cg1h1
# perimeter
# pco2atdepth2
# pco2atdepth1
# pco2(ppmv)
# pcc
# pb208(ug/l)
# pb
# particulatep(ug/l)
# particulateorgc(mg/l)
# p;soilpit(p1p20)
# p2o5
# p1mb
# p(μmoll1)
# p(μm)
# p(ug/ml)
# p
# othergrassseeds(bushels)
# othercattle
# other
# orthhoclase
# orp(mv)
# ohm.m
# oh
# oats(bushels)
# o3maximum
# o2pct
# mta
# mod
# mo
# milchcows
# midslp
# mica
# mgo
# mg25(ug/l)
# mg+2(μm)
# mg++(ueq/l)
# mg++(ppm)
# mg(umoll1)
# mg(umoll)
# mg(ug/ml)
# mg(mg/l)
# mg
# method
# metavariscite
# measuredstage
# maximumsoiltemp
# maximumrelativehumidity
# maxht
# maplesugar(lbs.)
# majax
# macroplot
# lvl9
# lvl2
# lutetiumdissolved
# lu
# lpmid
# loi
# litu
# litterfall
# litter
# list
# lidar
# li
# level(mm)
# leaflittermaterial
# ldo%
# ldo
# laz
# layer
# las
# lai;pcc
# lai
# la
# ksatsd
# ksatcv%
# ksat
# ka;vm/km(hr^1)
# k2o
# k+(μm)
# k+(ueq/l)
# k+(ppm)
# k(umoll1)
# k(umoll)
# k(ug/ml)
# k(mg/l)
# k
# irishpotatoes(bushels)
# ip(um/l)
# imagdiel(40cm)
# imagdiel(20cm)
# imagdiel(10cm)
# id
# i
# hydrology
# humidity
# hue
# ht
# hour
# horses
# hops(lbs.)
# holmiumdissolved
# ho
# hmprelativehumidity
# hix
# hhefe(mg/g)
# hhe9be(ug/g)
# hf
# hclp
# haolloysite
# h(mg/l)
# gw2wtemp
# growth(cm)
# group
# grossprimaryproductivity.
# grossprimaryproductivity
# goethite
# gisgeospatialdatabase
# gis
# gibbsite
# geology
# ge
# gd
# gcco2pct
# gcch4ppm
# gageht
# ga
# ftotdoc
# ftot
# foresttype
# foliardelta13c(o/oo)
# flaxseed(bushels)
# flax(lbs.)
# filtersize
# filtered(bareearth)hillshade
# filtered(bareearth)dem
# file1:site
# fieldtech
# fieldlabel
# fi
# fecitrate/ascorbateextractable
# fe57(umoll)
# fe56(ug/l)
# fe54(umoll)
# fe2o3(t)
# fe+3(μm)
# fe(umoll1)
# fe(ug/ml)
# fe(mg/l)
# fe(ii)
# fe
# family
# fagr
# f(μm)
# f(umoll1)
# f(mg/l)
# f
# evtboulder
# europiumdissolved
# eu
# est)
# erbiumdissolved
# er
# eqdiam
# empty
# emi
# ec(us/cm)
# ec(s/m)
# ec
# dysprosiumdissolved
# dy
# dtavg
# dsm
# dryweight
# dop(um/l)
# doc(ppm)
# doc
# do(mgl1)
# do(mg/l)
# do
# dissolvedorgp(ug/l)
# dissolvedorgc(ppm)
# dissolvedorgc(mg/l)
# digitalsurfacemodel
# dickite
# diameter(cm;atrootcollar)
# device
# depthtowatertable
# depthtobt
# depthtobedrock
# depthofsample(cm)
# depthm
# depthcm
# depth(mm)
# depth(cm)
# depth
# dems
# dem
# deltadofh2o
# delta1dofh2o
# delta18oofh2o.
# delta18oofh2o
# delta18o
# delta13cofdic
# degrees2theta
# degc)
# dd/mill
# dbh
# dayofyear
# datesamplecollected(m/d/yy)
# datemeasured
# datecollected(yyyymmdd)
# date(mm/dd/yyyy)
# date(m/d/yy)
# date
# dataloggeridbport
# dataloggeridaport
# d18o/mill
# d18o(permil)
# d181sigma
# d13cco2
# cz36
# cz35
# cz29
# cz28
# cz27
# cz26
# cz25
# cz24
# cz23
# cz22
# cz21
# cz20
# curvature
# cu63(ug/l)
# cu
# cs
# cristobalite
# cr52(ug/l)
# cr
# corr
# co59(ug/l)
# co2pct
# co2flux(μmolm2s1)
# co2flux(umol/m2)
# co2
# co
# cm(right)
# cm(left)
# cm
# cloverseed(bushels)
# cloudcover
# cl(μm)
# cl(umoll1)
# cl(ueq/l)
# cl(ppm)
# cl(mg/l)
# cl
# city
# circularity
# chroma
# cheese(lbs.)
# chargebal
# ceriumdissolved
# ce
# cdom
# cd
# cata
# cashvalueoffarm
# cao
# ca44(ug/l)
# ca43(ug/l)
# ca+2(μm)
# ca++(ueq/l)
# ca(umoll1)
# ca(umoll)
# ca(ug/ml)
# ca(mg/l)
# ca
# c%
# c
# butter(lbs.)
# buckwheat(bushels)
# br(mg/l)
# br
# bp
# block
# bix
# biota
# bi
# betaglucosidaseactivity
# betaglucosidase
# bedrock
# be
# barometricpress(mbar)
# baro
# barley(bushels)
# ba(μmoll1)
# ba(μm)
# ba(ug/ml)
# ba
# averagesoiltemp
# averagerelativehumidity
# averagepfd(moles)
# averagepfd
# averageo3
# averagelai
# augelite
# aspect(degree)
# aspect
# ascii
# as
# alk
# alcitrate/ascorbateextractable
# albite
# al3+
# al2o3
# al27(mg/l)
# al+3(μm)
# al(umoll1)
# al(umoll)
# al(ug/ml)
# al(mg/l)
# al
# airtempmax
# airtempavg
# airtemp(c)2m(max)
# airtemp(c)2m(avg)
# airtemp(c)2.5m(avg)
# airtemp(c)10m(max)
# airtemp(c)10m(avg)
# airtemp(c)
# airtcmax
# airtcavg
# airt
# aggregatestability;file2:site
# age(years).
# agcsum
# ag(μg/l)
# ag
# abspress
# abspres
# 5
# 4
# 3
# 2012dbh(cm)
# 2008dbh(cm)
# 2
# 10bemeteoric
# 10be(10^8atm/g)
# 1.5mo2
# 1.5mh2o
# 1.5mdegc
# 1.5mco2
# 1
# 0.5mo2
# 0.5mh2o
# 0.5mdegc
# 0.5mco2
# .kml
# (waterisotopes)dexcess/mill
# (ggp1:ggp1+ggp2)doc
# (ggp1:ggp1+ggp2)
# (fic'
# %o2atdepth2
# %o2atdepth1
# %diffchargebal
# %c
#
# μgsocg1
# μgeocg1
# δ2hreportablevalue(permil)
# δ2h(‰)
# δ2h(permil)
# δ2h
# δ18oreportablevalue(permil)
# δ18o(‰)
# δ18o
# δ13csoilrespiredco2
# δ13csoc
# δ13ceoc
# βglucosidaseactivity
# zr
# yttriumdissolved
# ytterbiumdissolved
# ymax
# year
# yb
# y
# xrf
# xrd
# xmax
# x
# wtemp
# wsscalavg
# wsmax
# wool(lbs.)
# woodymaterial
# wheat(bushels)
# watertempc
# watertemp(°c)
# watertemp(c)
# watertableraw(mv
# watertable(mmorcm)
# watertable
# waterquality
# waterlevel(ft)
# waterlevel
# waterflux
# waterdepth(cm)
# waterdepth
# w
# vllydpth
# vertical
# vermiculite
# vbat
# valueoforchardproducts(dollars)
# valueoflivestock
# value
# v(μm)
# v
# uva280.
# uva280
# uva254
# utme
# u
# twi
# tsargorodtsevite
# tritium1sigma
# tritium(tu)
# treetype
# treespecies
# treeid
# treegroup
# treegirth1.5m
# treeazimuth
# tree
# trapid
# tpi
# tp(um/l)
# totalzr(mg/g)
# totalppfd
# totalp(ug/l)
# totalp
# totalorgc(mg/l)
# totallittercollected
# totalfe(mg/g)
# totaldissolvedp(ugp/l)
# totaldissolvedp(ug/l)
# totalca(mg/g)
# totalal(mg/g)
# total9be(ug/g)
# total
# tobacco(lbs.)
# tmstamp(yyyymmddhh:mm:ss)
# tmstamp
# tm
# tl
# tio2
# tilepushprobedepth(cm)
# ti(ug/ml)
# ti
# thuliumdissolved
# th
# terbiumdissolved
# tds(mg1)
# tdp(um/l)
# tcdtavg
# tc(mg/l)
# tb
# taup
# ta
# t1c
# t+e(m/day)
# sweetpotatoes(bushels)
# suva280.
# suva280
# surfdegc
# sum+
# sum
# streamwaterchemistry
# stdht
# state
# start
# stagem
# stagediff
# stagecm
# ssurgoid
# ss
# sr(μm)
# sr(umoll1)
# sr(ug/ml)
# sr(mg/l)
# sr
# species
# spc(mscm1)
# solradtot
# solradposs
# soilvwc
# soiltype
# soiltracegases
# soiltexture
# soiltemp(c)22cm
# soiltemp(c)15cm
# soilt
# soils
# soilorder
# soilmoisture.
# soilmoisture(m3/m3)
# soilmoisture(40cm;m3/m3)
# soilmoisture(20cm;m3/m3)
# soilmoisture(10cm;m3/m3)
# soilmoisture
# soilheatflux(w/m^2)15cm
# soilec
# soileb
# soildepth
# soilco2(ppm)
# soilc
# so4s
# so4=(ueq/l)
# so4=(ppm)
# so42(μm)
# so42(umoll1)
# so4(mg/l)
# so4
# smp
# sm
# siteid
# site
# sio2icp(ppm)
# sio2(mg/l)
# sio2
# siicp(ppm)
# si28(ug/l)
# si28(mg/l)
# si(μm)
# si(umoll1)
# si(ug/ml)
# si(mg/l)
# si
# shortaxis
# sheep
# shapefiles
# shadedrelief
# semta
# selai
# seedetailsbelow)
# seedetailbelow)
# se
# scale
# sc
# sb
# sapfluxid
# sapflux
# sapflow
# sampletype
# samplemedium
# samplelabel
# sampleid
# sampledate
# sample
# samariumdissolved
# rye(bushels)
# rubidium
# rice(lbs.)
# rhmax
# rhavg
# rh2m(max)
# rh2m
# rh10m(max)
# rh10m
# rh1
# rh(max)
# rh
# residualtototal
# residualp
# relativehumidity.
# relativehumidity
# relativeage
# reflectivity(dbz)
# record
# recharge(m/day)
# realdiel(40cm)
# realdiel(20cm)
# realdiel(10cm)
# rb
# rasterimagedata
# quve
# qust
# quru
# qumo
# quickflow(m3/day)
# qufa
# quartz
# qual
# q(m^3/s)
# profc
# probe
# press
# pred
# precip
# praseodymiumdissolved
# pr
# pp(um/l)
# potasiumppm
# potasium
# poc
# po4p
# po4(mg/l)
# po4
# pmolpog1h1
# pmolbgg1h1
# pmolapg1h1
# plot
# plagioclase
# pita
# pit5temp(c)12cm
# pit4temp(c)11cm
# pit3temp(c)15cm
# pit2temp(c)15cm
# pit1temp(c)15cm
# pit
# piec
# pgch4cg1h1
# perimeter
# pco2atdepth2
# pco2atdepth1
# pco2(ppmv)
# pcc
# pb208(ug/l)
# pb
# particulatep(ug/l)
# particulateorgc(mg/l)
# p;soilpit(p1p20)
# p2o5
# p1mb
# p(μmoll1)
# p(μm)
# p(ug/ml)
# p
# othergrassseeds(bushels)
# othercattle
# other
# orthhoclase
# orp(mv)
# ohm.m
# oh
# oats(bushels)
# o3maximum
# o2pct
# mta
# mod
# mo
# milchcows
# midslp
# mica
# mgo
# mg25(ug/l)
# mg+2(μm)
# mg++(ueq/l)
# mg++(ppm)
# mg(umoll1)
# mg(umoll)
# mg(ug/ml)
# mg(mg/l)
# mg
# method
# metavariscite
# measuredstage
# maximumsoiltemp
# maximumrelativehumidity
# maxht
# maplesugar(lbs.)
# majax
# macroplot
# lvl9
# lvl2
# lutetiumdissolved
# lu
# lpmid
# loi
# litu
# litterfall
# litter
# list
# lidar
# li
# level(mm)
# leaflittermaterial
# ldo%
# ldo
# laz
# layer
# las
# lai;pcc
# lai
# la
# ksatsd
# ksatcv%
# ksat
# ka;vm/km(hr^1)
# k2o
# k+(μm)
# k+(ueq/l)
# k+(ppm)
# k(umoll1)
# k(umoll)
# k(ug/ml)
# k(mg/l)
# k
# irishpotatoes(bushels)
# ip(um/l)
# imagdiel(40cm)
# imagdiel(20cm)
# imagdiel(10cm)
# id
# i
# hydrology
# humidity
# hue
# ht
# hour
# horses
# hops(lbs.)
# holmiumdissolved
# ho
# hmprelativehumidity
# hix
# hhefe(mg/g)
# hhe9be(ug/g)
# hf
# hclp
# haolloysite
# h(mg/l)
# gw2wtemp
# growth(cm)
# group
# grossprimaryproductivity.
# grossprimaryproductivity
# goethite
# gisgeospatialdatabase
# gis
# gibbsite
# geology
# ge
# gd
# gcco2pct
# gcch4ppm
# gageht
# ga
# ftotdoc
# ftot
# foresttype
# foliardelta13c(o/oo)
# flaxseed(bushels)
# flax(lbs.)
# filtersize
# filtered(bareearth)hillshade
# filtered(bareearth)dem
# file1:site
# fieldtech
# fieldlabel
# fi
# fecitrate/ascorbateextractable
# fe57(umoll)
# fe56(ug/l)
# fe54(umoll)
# fe2o3(t)
# fe+3(μm)
# fe(umoll1)
# fe(ug/ml)
# fe(mg/l)
# fe(ii)
# fe
# family
# fagr
# f(μm)
# f(umoll1)
# f(mg/l)
# f
# evtboulder
# europiumdissolved
# eu
# est)
# erbiumdissolved
# er
# eqdiam
# empty
# emi
# ec(us/cm)
# ec(s/m)
# ec
# dysprosiumdissolved
# dy
# dtavg
# dsm
# dryweight
# dop(um/l)
# doc(ppm)
# doc
# do(mgl1)
# do(mg/l)
# do
# dissolvedorgp(ug/l)
# dissolvedorgc(ppm)
# dissolvedorgc(mg/l)
# digitalsurfacemodel
# dickite
# diameter(cm;atrootcollar)
# device
# depthtowatertable
# depthtobt
# depthtobedrock
# depthofsample(cm)
# depthm
# depthcm
# depth(mm)
# depth(cm)
# depth
# dems
# dem
# deltadofh2o
# delta1dofh2o
# delta18oofh2o.
# delta18oofh2o
# delta18o
# delta13cofdic
# degrees2theta
# degc)
# dd/mill
# dbh
# dayofyear
# datesamplecollected(m/d/yy)
# datemeasured
# datecollected(yyyymmdd)
# date(mm/dd/yyyy)
# date(m/d/yy)
# date
# dataloggeridbport
# dataloggeridaport
# d18o/mill
# d18o(permil)
# d181sigma
# d13cco2
# cz36
# cz35
# cz29
# cz28
# cz27
# cz26
# cz25
# cz24
# cz23
# cz22
# cz21
# cz20
# curvature
# cu63(ug/l)
# cu
# cs
# cristobalite
# cr52(ug/l)
# cr
# corr
# co59(ug/l)
# co2pct
# co2flux(μmolm2s1)
# co2flux(umol/m2)
# co2
# co
# cm(right)
# cm(left)
# cm
# cloverseed(bushels)
# cloudcover
# cl(μm)
# cl(umoll1)
# cl(ueq/l)
# cl(ppm)
# cl(mg/l)
# cl
# city
# circularity
# chroma
# cheese(lbs.)
# chargebal
# ceriumdissolved
# ce
# cdom
# cd
# cata
# cashvalueoffarm
# cao
# ca44(ug/l)
# ca43(ug/l)
# ca+2(μm)
# ca++(ueq/l)
# ca(umoll1)
# ca(umoll)
# ca(ug/ml)
# ca(mg/l)
# ca
# c%
# c
# butter(lbs.)
# buckwheat(bushels)
# br(mg/l)
# br
# bp
# block
# bix
# biota
# bi
# betaglucosidaseactivity
# betaglucosidase
# bedrock
# be
# barometricpress(mbar)
# baro
# barley(bushels)
# ba(μmoll1)
# ba(μm)
# ba(ug/ml)
# ba
# averagesoiltemp
# averagerelativehumidity
# averagepfd(moles)
# averagepfd
# averageo3
# averagelai
# augelite
# aspect(degree)
# aspect
# ascii
# as
# alk
# alcitrate/ascorbateextractable
# albite
# al3+
# al2o3
# al27(mg/l)
# al+3(μm)
# al(umoll1)
# al(umoll)
# al(ug/ml)
# al(mg/l)
# al
# airtempmax
# airtempavg
# airtemp(c)2m(max)
# airtemp(c)2m(avg)
# airtemp(c)2.5m(avg)
# airtemp(c)10m(max)
# airtemp(c)10m(avg)
# airtemp(c)
# airtcmax
# airtcavg
# airt
# aggregatestability;file2:site
# age(years).
# agcsum
# ag(μg/l)
# ag
# abspress
# abspres
# 5
# 4
# 3
# 2012dbh(cm)
# 2008dbh(cm)
# 2
# 10bemeteoric
# 10be(10^8atm/g)
# 1.5mo2
# 1.5mh2o
# 1.5mdegc
# 1.5mco2
# 1
# 0.5mo2
# 0.5mh2o
# 0.5mdegc
# 0.5mco2
# .kml
# (waterisotopes)dexcess/mill
# (ggp1:ggp1+ggp2)doc
# (ggp1:ggp1+ggp2)
# (fic'
# %o2atdepth2
# %o2atdepth1
# %diffchargebal
# %c
#
# μgsocg1
# μgeocg1
# δ2hreportablevalue(permil)
# δ2h(‰)
# δ2h(permil)
# δ2h
# δ18oreportablevalue(permil)
# δ18o(‰)
# δ18o
# δ13csoilrespiredco2
# δ13csoc
# δ13ceoc
# βglucosidaseactivity
# zr
# yttriumdissolved
# ytterbiumdissolved
# ymax
# year
# yb
# y
# xrf
# xrd
# xmax
# x
# wtemp
# wsscalavg
# wsmax
# wool(lbs.)
# woodymaterial
# wheat(bushels)
# watertempc
# watertemp(°c)
# watertemp(c)
# watertableraw(mv
# watertable(mmorcm)
# watertable
# waterquality
# waterlevel(ft)
# waterlevel
# waterflux
# waterdepth(cm)
# waterdepth
# w
# vllydpth
# vertical
# vermiculite
# vbat
# valueoforchardproducts(dollars)
# valueoflivestock
# value
# v(μm)
# v
# uva280.
# uva280
# uva254
# utme
# u
# twi
# tsargorodtsevite
# tritium1sigma
# tritium(tu)
# treetype
# treespecies
# treeid
# treegroup
# treegirth1.5m
# treeazimuth
# tree
# trapid
# tpi
# tp(um/l)
# totalzr(mg/g)
# totalppfd
# totalp(ug/l)
# totalp
# totalorgc(mg/l)
# totallittercollected
# totalfe(mg/g)
# totaldissolvedp(ugp/l)
# totaldissolvedp(ug/l)
# totalca(mg/g)
# totalal(mg/g)
# total9be(ug/g)
# total
# tobacco(lbs.)
# tmstamp(yyyymmddhh:mm:ss)
# tmstamp
# tm
# tl
# tio2
# tilepushprobedepth(cm)
# ti(ug/ml)
# ti
# thuliumdissolved
# th
# terbiumdissolved
# tds(mg1)
# tdp(um/l)
# tcdtavg
# tc(mg/l)
# tb
# taup
# ta
# t1c
# t+e(m/day)
# sweetpotatoes(bushels)
# suva280.
# suva280
# surfdegc
# sum+
# sum
# streamwaterchemistry
# stdht
# state
# start
# stagem
# stagediff
# stagecm
# ssurgoid
# ss
# sr(μm)
# sr(umoll1)
# sr(ug/ml)
# sr(mg/l)
# sr
# species
# spc(mscm1)
# solradtot
# solradposs
# soilvwc
# soiltype
# soiltracegases
# soiltexture
# soiltemp(c)22cm
# soiltemp(c)15cm
# soilt
# soils
# soilorder
# soilmoisture.
# soilmoisture(m3/m3)
# soilmoisture(40cm;m3/m3)
# soilmoisture(20cm;m3/m3)
# soilmoisture(10cm;m3/m3)
# soilmoisture
# soilheatflux(w/m^2)15cm
# soilec
# soileb
# soildepth
# soilco2(ppm)
# soilc
# so4s
# so4=(ueq/l)
# so4=(ppm)
# so42(μm)
# so42(umoll1)
# so4(mg/l)
# so4
# smp
# sm
# siteid
# site
# sio2icp(ppm)
# sio2(mg/l)
# sio2
# siicp(ppm)
# si28(ug/l)
# si28(mg/l)
# si(μm)
# si(umoll1)
# si(ug/ml)
# si(mg/l)
# si
# shortaxis
# sheep
# shapefiles
# shadedrelief
# semta
# selai
# seedetailsbelow)
# seedetailbelow)
# se
# scale
# sc
# sb
# sapfluxid
# sapflux
# sapflow
# sampletype
# samplemedium
# samplelabel
# sampleid
# sampledate
# sample
# samariumdissolved
# rye(bushels)
# rubidium
# rice(lbs.)
# rhmax
# rhavg
# rh2m(max)
# rh2m
# rh10m(max)
# rh10m
# rh1
# rh(max)
# rh
# residualtototal
# residualp
# relativehumidity.
# relativehumidity
# relativeage
# reflectivity(dbz)
# record
# recharge(m/day)
# realdiel(40cm)
# realdiel(20cm)
# realdiel(10cm)
# rb
# rasterimagedata
# quve
# qust
# quru
# qumo
# quickflow(m3/day)
# qufa
# quartz
# qual
# q(m^3/s)
# profc
# probe
# press
# pred
# precip
# praseodymiumdissolved
# pr
# pp(um/l)
# potasiumppm
# potasium
# poc
# po4p
# po4(mg/l)
# po4
# pmolpog1h1
# pmolbgg1h1
# pmolapg1h1
# plot
# plagioclase
# pita
# pit5temp(c)12cm
# pit4temp(c)11cm
# pit3temp(c)15cm
# pit2temp(c)15cm
# pit1temp(c)15cm
# pit
# piec
# pgch4cg1h1
# perimeter
# pco2atdepth2
# pco2atdepth1
# pco2(ppmv)
# pcc
# pb208(ug/l)
# pb
# particulatep(ug/l)
# particulateorgc(mg/l)
# p;soilpit(p1p20)
# p2o5
# p1mb
# p(μmoll1)
# p(μm)
# p(ug/ml)
# p
# othergrassseeds(bushels)
# othercattle
# other
# orthhoclase
# orp(mv)
# ohm.m
# oh
# oats(bushels)
# o3maximum
# o2pct
# mta
# mod
# mo
# milchcows
# midslp
# mica
# mgo
# mg25(ug/l)
# mg+2(μm)
# mg++(ueq/l)
# mg++(ppm)
# mg(umoll1)
# mg(umoll)
# mg(ug/ml)
# mg(mg/l)
# mg
# method
# metavariscite
# measuredstage
# maximumsoiltemp
# maximumrelativehumidity
# maxht
# maplesugar(lbs.)
# majax
# macroplot
# lvl9
# lvl2
# lutetiumdissolved
# lu
# lpmid
# loi
# litu
# litterfall
# litter
# list
# lidar
# li
# level(mm)
# leaflittermaterial
# ldo%
# ldo
# laz
# layer
# las
# lai;pcc
# lai
# la
# ksatsd
# ksatcv%
# ksat
# ka;vm/km(hr^1)
# k2o
# k+(μm)
# k+(ueq/l)
# k+(ppm)
# k(umoll1)
# k(umoll)
# k(ug/ml)
# k(mg/l)
# k
# irishpotatoes(bushels)
# ip(um/l)
# imagdiel(40cm)
# imagdiel(20cm)
# imagdiel(10cm)
# id
# i
# hydrology
# humidity
# hue
# ht
# hour
# horses
# hops(lbs.)
# holmiumdissolved
# ho
# hmprelativehumidity
# hix
# hhefe(mg/g)
# hhe9be(ug/g)
# hf
# hclp
# haolloysite
# h(mg/l)
# gw2wtemp
# growth(cm)
# group
# grossprimaryproductivity.
# grossprimaryproductivity
# goethite
# gisgeospatialdatabase
# gis
# gibbsite
# geology
# ge
# gd
# gcco2pct
# gcch4ppm
# gageht
# ga
# ftotdoc
# ftot
# foresttype
# foliardelta13c(o/oo)
# flaxseed(bushels)
# flax(lbs.)
# filtersize
# filtered(bareearth)hillshade
# filtered(bareearth)dem
# file1:site
# fieldtech
# fieldlabel
# fi
# fecitrate/ascorbateextractable
# fe57(umoll)
# fe56(ug/l)
# fe54(umoll)
# fe2o3(t)
# fe+3(μm)
# fe(umoll1)
# fe(ug/ml)
# fe(mg/l)
# fe(ii)
# fe
# family
# fagr
# f(μm)
# f(umoll1)
# f(mg/l)
# f
# evtboulder
# europiumdissolved
# eu
# est)
# erbiumdissolved
# er
# eqdiam
# empty
# emi
# ec(us/cm)
# ec(s/m)
# ec
# dysprosiumdissolved
# dy
# dtavg
# dsm
# dryweight
# dop(um/l)
# doc(ppm)
# doc
# do(mgl1)
# do(mg/l)
# do
# dissolvedorgp(ug/l)
# dissolvedorgc(ppm)
# dissolvedorgc(mg/l)
# digitalsurfacemodel
# dickite
# diameter(cm;atrootcollar)
# device
# depthtowatertable
# depthtobt
# depthtobedrock
# depthofsample(cm)
# depthm
# depthcm
# depth(mm)
# depth(cm)
# depth
# dems
# dem
# deltadofh2o
# delta1dofh2o
# delta18oofh2o.
# delta18oofh2o
# delta18o
# delta13cofdic
# degrees2theta
# degc)
# dd/mill
# dbh
# dayofyear
# datesamplecollected(m/d/yy)
# datemeasured
# datecollected(yyyymmdd)
# date(mm/dd/yyyy)
# date(m/d/yy)
# date
# dataloggeridbport
# dataloggeridaport
# d18o/mill
# d18o(permil)
# d181sigma
# d13cco2
# cz36
# cz35
# cz29
# cz28
# cz27
# cz26
# cz25
# cz24
# cz23
# cz22
# cz21
# cz20
# curvature
# cu63(ug/l)
# cu
# cs
# cristobalite
# cr52(ug/l)
# cr
# corr
# co59(ug/l)
# co2pct
# co2flux(μmolm2s1)
# co2flux(umol/m2)
# co2
# co
# cm(right)
# cm(left)
# cm
# cloverseed(bushels)
# cloudcover
# cl(μm)
# cl(umoll1)
# cl(ueq/l)
# cl(ppm)
# cl(mg/l)
# cl
# city
# circularity
# chroma
# cheese(lbs.)
# chargebal
# ceriumdissolved
# ce
# cdom
# cd
# cata
# cashvalueoffarm
# cao
# ca44(ug/l)
# ca43(ug/l)
# ca+2(μm)
# ca++(ueq/l)
# ca(umoll1)
# ca(umoll)
# ca(ug/ml)
# ca(mg/l)
# ca
# c%
# c
# butter(lbs.)
# buckwheat(bushels)
# br(mg/l)
# br
# bp
# block
# bix
# biota
# bi
# betaglucosidaseactivity
# betaglucosidase
# bedrock
# be
# barometricpress(mbar)
# baro
# barley(bushels)
# ba(μmoll1)
# ba(μm)
# ba(ug/ml)
# ba
# averagesoiltemp
# averagerelativehumidity
# averagepfd(moles)
# averagepfd
# averageo3
# averagelai
# augelite
# aspect(degree)
# aspect
# ascii
# as
# alk
# alcitrate/ascorbateextractable
# albite
# al3+
# al2o3
# al27(mg/l)
# al+3(μm)
# al(umoll1)
# al(umoll)
# al(ug/ml)
# al(mg/l)
# al
# airtempmax
# airtempavg
# airtemp(c)2m(max)
# airtemp(c)2m(avg)
# airtemp(c)2.5m(avg)
# airtemp(c)10m(max)
# airtemp(c)10m(avg)
# airtemp(c)
# airtcmax
# airtcavg
# airt
# aggregatestability;file2:site
# age(years).
# agcsum
# ag(μg/l)
# ag
# abspress
# abspres
# 5
# 4
# 3
# 2012dbh(cm)
# 2008dbh(cm)
# 2
# 10bemeteoric
# 10be(10^8atm/g)
# 1.5mo2
# 1.5mh2o
# 1.5mdegc
# 1.5mco2
# 1
# 0.5mo2
# 0.5mh2o
# 0.5mdegc
# 0.5mco2
# .kml
# (waterisotopes)dexcess/mill
# (ggp1:ggp1+ggp2)doc
# (ggp1:ggp1+ggp2)
# (fic'
# %o2atdepth2
# %o2atdepth1
# %diffchargebal
# %c

# %%
matchVariables
# Out:
# []

# %%
with open('noMatchVar.txt','w') as f:
    f.write('\n'.join('%s' % x for x in variables))
